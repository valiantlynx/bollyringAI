# %%
import pandas as pd
import json
import glob
import logging
import time

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

start_time = time.time()
logging.info("Loading workers data and calculating recommendation scores...")
# Out:
# 2024-10-30 19:04:10,373 - INFO - Loading workers data and calculating recommendation scores...

# %%
# Load workers data and format correctly
workers_df = pd.read_json('extracted/workers.json').transpose().reset_index()
workers_df.columns = ['worker_id', 'name', 'base_salary']

# %%
workers_df
# Out:
#                                   worker_id                name base_salary
# 0    w_eb5ca7e7-197b-4128-9cdd-17b8d7d07803         Efren Selva       10119
# 1    w_ad84fb4e-5229-4c19-91e7-5e5cf8d3f20c          Alan Brown       10715
# 2    w_653b3a89-c5fa-466b-a477-f0c09a724cdd        Douglas Case        8259
# 3    w_7fbf0deb-0c65-449a-91ee-0e9e8cff4d0c       Christa Scott       11672
# 4    w_cf0ff121-da11-4b5c-b191-4d895ce97512   Christopher Greer        9408
# ..                                      ...                 ...         ...
# 750  w_972693d7-5edb-4499-abcb-98861d5a72e8       Anthony Nagel       10873
# 751  w_4d6a56fd-1d07-477f-b86a-2ced18e96076        Roger Doubet        9881
# 752  w_62aff065-2e41-4d62-a64e-a6c5783ef77a       Randall Clark        9610
# 753  w_46c17e47-9b03-482a-9d91-eeabb5eb1b84  Eleanor Williamson       10455
# 754  w_f5400776-c6cc-4563-b835-b5ee56242aa1         Jack Schram       14756
#
# [755 rows x 3 columns]

# %%
# Load and flatten reports data for worker performance
reports_records = []
for file_path in glob.glob('extracted/previous_reports/*.json'):
    reports_records.extend(pd.read_json(file_path).to_dict(orient='records'))
reports_df = pd.DataFrame(reports_records)

# %%
reports_df
# Out:
#                                       call_id  \
# 0      c_a317abc5-a7e1-40c3-b486-c4eefdf8be05
# 1      c_256844cb-b710-4da7-8f95-238a7fdd5261
# 2      c_46bfdc38-5130-4e08-9918-4851d84930ce
# 3      c_497ac5ca-8ff3-4773-968c-2e300486c35d
# 4      c_97384374-b420-4259-aaa9-f2e1571928cb
# ...                                       ...
# 72511  c_282338ea-b4a3-4d55-801c-1935c08be259
# 72512  c_9f076c7e-aa1f-44e2-a904-ec7daaec52c4
# 72513  c_bece22d1-0ba0-4208-91f8-366c8267177c
# 72514  c_ac55b479-d0ad-4c68-a637-87b3c360ceb9
# 72515  c_5a9ca763-3a01-491b-9288-e4e17fce0abb
#
#                                     worker_id  call_time  likely_to_recommend  \
# 0      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  57.057332                  1.0
# 1      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  69.294334                  1.0
# 2      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  70.794334                  1.0
# 3      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  54.379299                  1.0
# 4      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  77.457332                  1.0
# ...                                       ...        ...                  ...
# 72511  w_ff6501e8-b49a-4512-a9eb-e06565d21355  37.453295                  1.0
# 72512  w_ff6501e8-b49a-4512-a9eb-e06565d21355  62.093346                  1.0
# 72513  w_ff6501e8-b49a-4512-a9eb-e06565d21355  61.482360                  1.0
# 72514  w_ff6501e8-b49a-4512-a9eb-e06565d21355  32.353295                  1.0
# 72515  w_ff6501e8-b49a-4512-a9eb-e06565d21355  57.151490                  1.0
#
#        professional_score  call_profit
# 0                     NaN          695
# 1                     NaN          735
# 2                     NaN          735
# 3                     NaN          532
# 4                     NaN          834
# ...                   ...          ...
# 72511                 NaN          705
# 72512                 NaN          780
# 72513                 NaN          864
# 72514                 NaN          564
# 72515                 NaN          690
#
# [72516 rows x 6 columns]

# %%
# Calculate average recommendation score for each worker
worker_performance = reports_df.groupby('worker_id')['likely_to_recommend'].mean().reset_index()
worker_performance.columns = ['worker_id', 'avg_recommendation_score']

# Merge performance data with workers
workers_df = workers_df.merge(worker_performance, on='worker_id', how='left')

# %%
workers_df
# Out:
#                                   worker_id                name base_salary  \
# 0    w_eb5ca7e7-197b-4128-9cdd-17b8d7d07803         Efren Selva       10119
# 1    w_ad84fb4e-5229-4c19-91e7-5e5cf8d3f20c          Alan Brown       10715
# 2    w_653b3a89-c5fa-466b-a477-f0c09a724cdd        Douglas Case        8259
# 3    w_7fbf0deb-0c65-449a-91ee-0e9e8cff4d0c       Christa Scott       11672
# 4    w_cf0ff121-da11-4b5c-b191-4d895ce97512   Christopher Greer        9408
# ..                                      ...                 ...         ...
# 750  w_972693d7-5edb-4499-abcb-98861d5a72e8       Anthony Nagel       10873
# 751  w_4d6a56fd-1d07-477f-b86a-2ced18e96076        Roger Doubet        9881
# 752  w_62aff065-2e41-4d62-a64e-a6c5783ef77a       Randall Clark        9610
# 753  w_46c17e47-9b03-482a-9d91-eeabb5eb1b84  Eleanor Williamson       10455
# 754  w_f5400776-c6cc-4563-b835-b5ee56242aa1         Jack Schram       14756
#
#      avg_recommendation_score
# 0                    1.816522
# 1                    1.512500
# 2                    1.486364
# 3                    1.641053
# 4                    1.622093
# ..                        ...
# 750                  1.524211
# 751                  1.368132
# 752                  1.747778
# 753                  1.510465
# 754                  7.291386
#
# [755 rows x 4 columns]

# %%
# Define thresholds based on recommendation score
def assign_difficulty_threshold(score):
    if score > 2.2:
        return 'hard'
    elif 1.8 <= score <= 2.2:
        return 'medium'
    else:
        return 'easy'

# %%
# Assign difficulty preference to each worker
workers_df['assigned_difficulty'] = workers_df['avg_recommendation_score'].apply(assign_difficulty_threshold)

logging.info("Loading and flattening feature calls data...")
# Out:
# 2024-10-30 19:09:28,361 - INFO - Loading and flattening feature calls data...

# %%
workers_df
# Out:
#                                   worker_id                name base_salary  \
# 0    w_eb5ca7e7-197b-4128-9cdd-17b8d7d07803         Efren Selva       10119
# 1    w_ad84fb4e-5229-4c19-91e7-5e5cf8d3f20c          Alan Brown       10715
# 2    w_653b3a89-c5fa-466b-a477-f0c09a724cdd        Douglas Case        8259
# 3    w_7fbf0deb-0c65-449a-91ee-0e9e8cff4d0c       Christa Scott       11672
# 4    w_cf0ff121-da11-4b5c-b191-4d895ce97512   Christopher Greer        9408
# ..                                      ...                 ...         ...
# 750  w_972693d7-5edb-4499-abcb-98861d5a72e8       Anthony Nagel       10873
# 751  w_4d6a56fd-1d07-477f-b86a-2ced18e96076        Roger Doubet        9881
# 752  w_62aff065-2e41-4d62-a64e-a6c5783ef77a       Randall Clark        9610
# 753  w_46c17e47-9b03-482a-9d91-eeabb5eb1b84  Eleanor Williamson       10455
# 754  w_f5400776-c6cc-4563-b835-b5ee56242aa1         Jack Schram       14756
#
#      avg_recommendation_score assigned_difficulty
# 0                    1.816522              medium
# 1                    1.512500                easy
# 2                    1.486364                easy
# 3                    1.641053                easy
# 4                    1.622093                easy
# ..                        ...                 ...
# 750                  1.524211                easy
# 751                  1.368132                easy
# 752                  1.747778                easy
# 753                  1.510465                easy
# 754                  7.291386                hard
#
# [755 rows x 5 columns]

# %%
# Load feature calls data
feature_records = []
for file_path in glob.glob('extracted/feature_calls/*.json'):
    with open(file_path) as f:
        data = json.load(f)
    for location, calls in data.items():
        for call_id, call_info in calls.items():
            call_info['call_id'] = call_id
            call_info['location'] = location
            feature_records.append(call_info)
feature_calls_df = pd.DataFrame(feature_records)

logging.info("Starting call assignments to workers based on difficulty and performance...")
# Out:
# 2024-10-30 19:10:15,453 - INFO - Starting call assignments to workers based on difficulty and performance...

# %%
feature_calls_df
# Out:
#                               date tlf_number               technical_problem  \
# 0       2024-10-23 16:54:39.515508   72345741                  teams_problems
# 1       2024-10-23 12:18:18.515647   53336166  basic_hardware_troubleshooting
# 2       2024-10-20 01:42:41.515693   81959025            email_related_issues
# 3       2024-10-24 12:14:40.515734   96315388     device_and_peripheral_setup
# 4       2024-10-24 19:24:07.515775   54054590               internet_problems
# ...                            ...        ...                             ...
# 257096  2024-10-22 17:11:21.910960   35675011                   zoom_problems
# 257097  2024-10-23 09:14:03.910999   22767682               internet_problems
# 257098  2024-10-19 17:31:44.911038   24957531            email_related_issues
# 257099  2024-10-20 17:10:37.911077   00563223               internet_problems
# 257100  2024-10-25 17:24:56.911115   31411164     account_and_security_issues
#
#        difficulty  commission                                 call_id  \
# 0          medium       665.0  c_5e239e86-20f4-4053-a77b-a01dd3971aad
# 1            easy       576.0  c_1cbe224b-804b-4b30-bf78-198feea748f8
# 2          medium       700.0  c_ca2f35cc-47fb-446f-a8ad-3c0360edb98c
# 3          medium       705.0  c_59b1c1cc-6362-4edd-aed8-720536d733e6
# 4          medium       680.0  c_69e87302-cad8-42a3-9fb2-e64c0a4b14e4
# ...           ...         ...                                     ...
# 257096       hard       834.0  c_2b052e28-f48f-4c85-8b75-f73f27ef75f0
# 257097     medium       680.0  c_65dc01b2-5091-40d1-9838-c8a749b3f766
# 257098     medium       700.0  c_827e75d4-1948-433a-ad5d-f2bdf083ec71
# 257099     medium       680.0  c_68b59f6b-00e7-4529-a353-d9ded93226ce
# 257100       easy       568.0  c_8a3066c6-1ef4-4035-baac-ead3338e04e0
#
#          location
# 0       bangalore
# 1       bangalore
# 2       bangalore
# 3       bangalore
# 4       bangalore
# ...           ...
# 257096  hyderabad
# 257097  hyderabad
# 257098  hyderabad
# 257099  hyderabad
# 257100  hyderabad
#
# [257101 rows x 7 columns]

# %%
# Assign calls to workers based on difficulty and performance
def assign_calls_to_workers(calls_df, workers_df):
    schedule = {worker_id: [] for worker_id in workers_df['worker_id']}
    total_calls = len(calls_df)
    
    for i, (_, call) in enumerate(calls_df.iterrows(), 1):
        eligible_workers = workers_df[workers_df['assigned_difficulty'] == call['difficulty']]
        eligible_workers = eligible_workers.sort_values(by='avg_recommendation_score', ascending=False)
        top_worker = eligible_workers.iloc[0]['worker_id']
        schedule[top_worker].append(call['call_id'])
        
        # Calculate and log progress
        if i % 100 == 0 or i == total_calls:
            elapsed = time.time() - start_time
            remaining = (elapsed / i) * (total_calls - i)
            logging.info(f"Assigned {i}/{total_calls} calls. Estimated time remaining: {remaining:.2f} seconds.")
    
    return schedule

call_schedule = assign_calls_to_workers(feature_calls_df, workers_df)

logging.info("Saving generated schedule to 'generated_schedule.json'...")
# Out:
# 2024-10-30 19:05:51,106 - INFO - Assigned 100/257101 calls. Estimated time remaining: 258883.16 seconds.
# 2024-10-30 19:05:51,156 - INFO - Assigned 200/257101 calls. Estimated time remaining: 129455.82 seconds.
# 2024-10-30 19:05:51,277 - INFO - Assigned 300/257101 calls. Estimated time remaining: 86373.99 seconds.
# 2024-10-30 19:05:51,317 - INFO - Assigned 400/257101 calls. Estimated time remaining: 64781.15 seconds.
# 2024-10-30 19:05:51,367 - INFO - Assigned 500/257101 calls. Estimated time remaining: 51830.13 seconds.
# 2024-10-30 19:05:51,426 - INFO - Assigned 600/257101 calls. Estimated time remaining: 43200.16 seconds.
# 2024-10-30 19:05:51,480 - INFO - Assigned 700/257101 calls. Estimated time remaining: 37034.20 seconds.
# 2024-10-30 19:05:51,528 - INFO - Assigned 800/257101 calls. Estimated time remaining: 32407.62 seconds.
# 2024-10-30 19:05:51,586 - INFO - Assigned 900/257101 calls. Estimated time remaining: 28812.14 seconds.
# 2024-10-30 19:05:51,641 - INFO - Assigned 1000/257101 calls. Estimated time remaining: 25934.76 seconds.
# 2024-10-30 19:05:51,682 - INFO - Assigned 1100/257101 calls. Estimated time remaining: 23577.47 seconds.
# 2024-10-30 19:05:51,741 - INFO - Assigned 1200/257101 calls. Estimated time remaining: 21616.76 seconds.
# 2024-10-30 19:05:51,790 - INFO - Assigned 1300/257101 calls. Estimated time remaining: 19955.68 seconds.
# 2024-10-30 19:05:51,847 - INFO - Assigned 1400/257101 calls. Estimated time remaining: 18533.47 seconds.
# 2024-10-30 19:05:51,896 - INFO - Assigned 1500/257101 calls. Estimated time remaining: 17299.52 seconds.
# 2024-10-30 19:05:51,962 - INFO - Assigned 1600/257101 calls. Estimated time remaining: 16222.50 seconds.
# 2024-10-30 19:05:52,016 - INFO - Assigned 1700/257101 calls. Estimated time remaining: 15270.45 seconds.
# 2024-10-30 19:05:52,059 - INFO - Assigned 1800/257101 calls. Estimated time remaining: 14422.50 seconds.
# 2024-10-30 19:05:52,108 - INFO - Assigned 1900/257101 calls. Estimated time remaining: 13664.63 seconds.
# 2024-10-30 19:05:52,166 - INFO - Assigned 2000/257101 calls. Estimated time remaining: 12983.74 seconds.
# 2024-10-30 19:05:52,223 - INFO - Assigned 2100/257101 calls. Estimated time remaining: 12367.56 seconds.
# 2024-10-30 19:05:52,273 - INFO - Assigned 2200/257101 calls. Estimated time remaining: 11806.48 seconds.
# 2024-10-30 19:05:52,327 - INFO - Assigned 2300/257101 calls. Estimated time remaining: 11294.73 seconds.
# 2024-10-30 19:05:52,375 - INFO - Assigned 2400/257101 calls. Estimated time remaining: 10824.96 seconds.
# 2024-10-30 19:05:52,426 - INFO - Assigned 2500/257101 calls. Estimated time remaining: 10393.10 seconds.
# 2024-10-30 19:05:52,481 - INFO - Assigned 2600/257101 calls. Estimated time remaining: 9994.81 seconds.
# 2024-10-30 19:05:52,531 - INFO - Assigned 2700/257101 calls. Estimated time remaining: 9625.58 seconds.
# 2024-10-30 19:05:52,581 - INFO - Assigned 2800/257101 calls. Estimated time remaining: 9282.65 seconds.
# 2024-10-30 19:05:52,629 - INFO - Assigned 2900/257101 calls. Estimated time remaining: 8963.32 seconds.
# 2024-10-30 19:05:52,679 - INFO - Assigned 3000/257101 calls. Estimated time remaining: 8665.32 seconds.
# 2024-10-30 19:05:52,728 - INFO - Assigned 3100/257101 calls. Estimated time remaining: 8386.50 seconds.
# 2024-10-30 19:05:52,776 - INFO - Assigned 3200/257101 calls. Estimated time remaining: 8125.08 seconds.
# 2024-10-30 19:05:52,834 - INFO - Assigned 3300/257101 calls. Estimated time remaining: 7880.20 seconds.
# 2024-10-30 19:05:52,883 - INFO - Assigned 3400/257101 calls. Estimated time remaining: 7649.06 seconds.
# 2024-10-30 19:05:52,932 - INFO - Assigned 3500/257101 calls. Estimated time remaining: 7431.14 seconds.
# 2024-10-30 19:05:52,990 - INFO - Assigned 3600/257101 calls. Estimated time remaining: 7225.96 seconds.
# 2024-10-30 19:05:53,039 - INFO - Assigned 3700/257101 calls. Estimated time remaining: 7031.22 seconds.
# 2024-10-30 19:05:53,092 - INFO - Assigned 3800/257101 calls. Estimated time remaining: 6847.03 seconds.
# 2024-10-30 19:05:53,137 - INFO - Assigned 3900/257101 calls. Estimated time remaining: 6671.75 seconds.
# 2024-10-30 19:05:53,186 - INFO - Assigned 4000/257101 calls. Estimated time remaining: 6505.51 seconds.
# 2024-10-30 19:05:53,228 - INFO - Assigned 4100/257101 calls. Estimated time remaining: 6346.89 seconds.
# 2024-10-30 19:05:53,278 - INFO - Assigned 4200/257101 calls. Estimated time remaining: 6196.38 seconds.
# 2024-10-30 19:05:53,326 - INFO - Assigned 4300/257101 calls. Estimated time remaining: 6052.69 seconds.
# 2024-10-30 19:05:53,366 - INFO - Assigned 4400/257101 calls. Estimated time remaining: 5915.10 seconds.
# 2024-10-30 19:05:53,423 - INFO - Assigned 4500/257101 calls. Estimated time remaining: 5784.54 seconds.
# 2024-10-30 19:05:53,464 - INFO - Assigned 4600/257101 calls. Estimated time remaining: 5658.79 seconds.
# 2024-10-30 19:05:53,519 - INFO - Assigned 4700/257101 calls. Estimated time remaining: 5539.17 seconds.
# 2024-10-30 19:05:53,574 - INFO - Assigned 4800/257101 calls. Estimated time remaining: 5424.53 seconds.
# 2024-10-30 19:05:53,626 - INFO - Assigned 4900/257101 calls. Estimated time remaining: 5314.35 seconds.
# 2024-10-30 19:05:53,667 - INFO - Assigned 5000/257101 calls. Estimated time remaining: 5208.08 seconds.
# 2024-10-30 19:05:53,719 - INFO - Assigned 5100/257101 calls. Estimated time remaining: 5106.52 seconds.
# 2024-10-30 19:05:53,765 - INFO - Assigned 5200/257101 calls. Estimated time remaining: 5008.54 seconds.
# 2024-10-30 19:05:53,819 - INFO - Assigned 5300/257101 calls. Estimated time remaining: 4914.68 seconds.
# 2024-10-30 19:05:53,864 - INFO - Assigned 5400/257101 calls. Estimated time remaining: 4823.84 seconds.
# 2024-10-30 19:05:53,920 - INFO - Assigned 5500/257101 calls. Estimated time remaining: 4736.79 seconds.
# 2024-10-30 19:05:53,961 - INFO - Assigned 5600/257101 calls. Estimated time remaining: 4652.20 seconds.
# 2024-10-30 19:05:54,010 - INFO - Assigned 5700/257101 calls. Estimated time remaining: 4570.93 seconds.
# 2024-10-30 19:05:54,059 - INFO - Assigned 5800/257101 calls. Estimated time remaining: 4492.46 seconds.
# 2024-10-30 19:05:54,120 - INFO - Assigned 5900/257101 calls. Estimated time remaining: 4417.16 seconds.
# 2024-10-30 19:05:54,166 - INFO - Assigned 6000/257101 calls. Estimated time remaining: 4343.74 seconds.
# 2024-10-30 19:05:54,220 - INFO - Assigned 6100/257101 calls. Estimated time remaining: 4273.05 seconds.
# 2024-10-30 19:05:54,270 - INFO - Assigned 6200/257101 calls. Estimated time remaining: 4204.47 seconds.
# 2024-10-30 19:05:54,313 - INFO - Assigned 6300/257101 calls. Estimated time remaining: 4137.82 seconds.
# 2024-10-30 19:05:54,370 - INFO - Assigned 6400/257101 calls. Estimated time remaining: 4073.78 seconds.
# 2024-10-30 19:05:54,422 - INFO - Assigned 6500/257101 calls. Estimated time remaining: 4011.49 seconds.
# 2024-10-30 19:05:54,465 - INFO - Assigned 6600/257101 calls. Estimated time remaining: 3950.78 seconds.
# 2024-10-30 19:05:54,522 - INFO - Assigned 6700/257101 calls. Estimated time remaining: 3892.38 seconds.
# 2024-10-30 19:05:54,571 - INFO - Assigned 6800/257101 calls. Estimated time remaining: 3835.42 seconds.
# 2024-10-30 19:05:54,620 - INFO - Assigned 6900/257101 calls. Estimated time remaining: 3780.11 seconds.
# 2024-10-30 19:05:54,670 - INFO - Assigned 7000/257101 calls. Estimated time remaining: 3726.39 seconds.
# 2024-10-30 19:05:54,720 - INFO - Assigned 7100/257101 calls. Estimated time remaining: 3674.21 seconds.
# 2024-10-30 19:05:54,768 - INFO - Assigned 7200/257101 calls. Estimated time remaining: 3623.38 seconds.
# 2024-10-30 19:05:54,817 - INFO - Assigned 7300/257101 calls. Estimated time remaining: 3573.98 seconds.
# 2024-10-30 19:05:54,857 - INFO - Assigned 7400/257101 calls. Estimated time remaining: 3525.64 seconds.
# 2024-10-30 19:05:54,906 - INFO - Assigned 7500/257101 calls. Estimated time remaining: 3478.87 seconds.
# 2024-10-30 19:05:54,963 - INFO - Assigned 7600/257101 calls. Estimated time remaining: 3433.59 seconds.
# 2024-10-30 19:05:55,012 - INFO - Assigned 7700/257101 calls. Estimated time remaining: 3389.21 seconds.
# 2024-10-30 19:05:55,060 - INFO - Assigned 7800/257101 calls. Estimated time remaining: 3345.97 seconds.
# 2024-10-30 19:05:55,109 - INFO - Assigned 7900/257101 calls. Estimated time remaining: 3303.83 seconds.
# 2024-10-30 19:05:55,158 - INFO - Assigned 8000/257101 calls. Estimated time remaining: 3262.75 seconds.
# 2024-10-30 19:05:55,207 - INFO - Assigned 8100/257101 calls. Estimated time remaining: 3222.68 seconds.
# 2024-10-30 19:05:55,255 - INFO - Assigned 8200/257101 calls. Estimated time remaining: 3183.57 seconds.
# 2024-10-30 19:05:55,310 - INFO - Assigned 8300/257101 calls. Estimated time remaining: 3145.59 seconds.
# 2024-10-30 19:05:55,353 - INFO - Assigned 8400/257101 calls. Estimated time remaining: 3108.17 seconds.
# 2024-10-30 19:05:55,411 - INFO - Assigned 8500/257101 calls. Estimated time remaining: 3072.05 seconds.
# 2024-10-30 19:05:55,452 - INFO - Assigned 8600/257101 calls. Estimated time remaining: 3036.30 seconds.
# 2024-10-30 19:05:55,501 - INFO - Assigned 8700/257101 calls. Estimated time remaining: 3001.60 seconds.
# 2024-10-30 19:05:55,551 - INFO - Assigned 8800/257101 calls. Estimated time remaining: 2967.68 seconds.
# 2024-10-30 19:05:55,598 - INFO - Assigned 8900/257101 calls. Estimated time remaining: 2934.49 seconds.
# 2024-10-30 19:05:55,650 - INFO - Assigned 9000/257101 calls. Estimated time remaining: 2902.13 seconds.
# 2024-10-30 19:05:55,701 - INFO - Assigned 9100/257101 calls. Estimated time remaining: 2870.47 seconds.
# 2024-10-30 19:05:55,743 - INFO - Assigned 9200/257101 calls. Estimated time remaining: 2839.26 seconds.
# 2024-10-30 19:05:55,800 - INFO - Assigned 9300/257101 calls. Estimated time remaining: 2809.13 seconds.
# 2024-10-30 19:05:55,841 - INFO - Assigned 9400/257101 calls. Estimated time remaining: 2779.21 seconds.
# 2024-10-30 19:05:55,886 - INFO - Assigned 9500/257101 calls. Estimated time remaining: 2750.00 seconds.
# 2024-10-30 19:05:55,940 - INFO - Assigned 9600/257101 calls. Estimated time remaining: 2721.66 seconds.
# 2024-10-30 19:05:55,992 - INFO - Assigned 9700/257101 calls. Estimated time remaining: 2693.83 seconds.
# 2024-10-30 19:05:56,038 - INFO - Assigned 9800/257101 calls. Estimated time remaining: 2666.42 seconds.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 20
#      16             logging.info(f"Assigned {i}/{total_calls} calls. Estimated time remaining: {remaining:.2f} seconds.")
#      18     return schedule
# ---> 20 call_schedule = assign_calls_to_workers(feature_calls_df, workers_df)
#      22 logging.info("Saving generated schedule to 'generated_schedule.json'...")
#
# Cell In[8], line 8, in assign_calls_to_workers(calls_df, workers_df)
#       6 for i, (_, call) in enumerate(calls_df.iterrows(), 1):
#       7     eligible_workers = workers_df[workers_df['assigned_difficulty'] == call['difficulty']]
# ----> 8     eligible_workers = eligible_workers.sort_values(by='avg_recommendation_score', ascending=False)
#       9     top_worker = eligible_workers.iloc[0]['worker_id']
#      10     schedule[top_worker].append(call['call_id'])
#
# File c:\Users\gorme\projects\bollyringAI\.venv\lib\site-packages\pandas\core\frame.py:7219, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7216     else:
#    7217         return result
# -> 7219 new_data = self._mgr.take(
#    7220     indexer, axis=self._get_block_manager_axis(axis), verify=False
#    7221 )
#    7223 if ignore_index:
#    7224     new_data.set_axis(
#    7225         self._get_block_manager_axis(axis), default_index(len(indexer))
#    7226     )
#
# File c:\Users\gorme\projects\bollyringAI\.venv\lib\site-packages\pandas\core\internals\managers.py:894, in BaseBlockManager.take(self, indexer, axis, verify)
#     891 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     893 new_labels = self.axes[axis].take(indexer)
# --> 894 return self.reindex_indexer(
#     895     new_axis=new_labels,
#     896     indexer=indexer,
#     897     axis=axis,
#     898     allow_dups=True,
#     899     copy=None,
#     900 )
#
# File c:\Users\gorme\projects\bollyringAI\.venv\lib\site-packages\pandas\core\internals\managers.py:687, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
# --> 687     new_blocks = [
#     688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File c:\Users\gorme\projects\bollyringAI\.venv\lib\site-packages\pandas\core\internals\managers.py:688, in <listcomp>(.0)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
#     687     new_blocks = [
# --> 688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File c:\Users\gorme\projects\bollyringAI\.venv\lib\site-packages\pandas\core\internals\blocks.py:1307, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1304     allow_fill = True
#    1306 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1307 new_values = algos.take_nd(
#    1308     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1309 )
#    1311 # Called from three places in managers, all of which satisfy
#    1312 #  these assertions
#    1313 if isinstance(self, ExtensionBlock):
#    1314     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1315     #  algos.take_nd call above.
#
# File c:\Users\gorme\projects\bollyringAI\.venv\lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File c:\Users\gorme\projects\bollyringAI\.venv\lib\site-packages\pandas\core\array_algos\take.py:157, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     155     out = np.empty(out_shape, dtype=dtype, order="F")
#     156 else:
# --> 157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
#     162 func(arr, indexer, out, fill_value)
#
# KeyboardInterrupt:

# %%
# Save the schedule in the required format
output_schedule = {worker_id: calls for worker_id, calls in call_schedule.items()}

with open('generated_schedule.json', 'w') as outfile:
    json.dump(output_schedule, outfile, indent=4)

total_time = time.time() - start_time
logging.info(f"Call schedule generated and saved to 'generated_schedule.json' in {total_time:.2f} seconds.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Save the schedule in the required format
# ----> 2 output_schedule = {worker_id: calls for worker_id, calls in call_schedule.items()}
#       4 with open('generated_schedule.json', 'w') as outfile:
#       5     json.dump(output_schedule, outfile, indent=4)
#
# NameError: name 'call_schedule' is not defined
