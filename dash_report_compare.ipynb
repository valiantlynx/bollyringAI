# %%
import pandas as pd
import json
import glob

# %%
# Load workers data and format correctly
workers_df = pd.read_json('extracted/workers.json').transpose().reset_index()
workers_df.columns = ['worker_id', 'name', 'base_salary']

# %%
# Load prices.json as a dictionary and convert to DataFrame
with open('Week1/prices.json') as f:
    prices_data = json.load(f)
prices_df = pd.DataFrame(list(prices_data.items()), columns=['technical_problem', 'price'])

# %%
# Function to load and flatten data from multiple JSON files in a directory
def load_and_flatten_data(directory, key_field):
    records = []
    for file_path in glob.glob(f'{directory}/*.json'):
        with open(file_path) as f:
            data = json.load(f)
        for location, calls in data.items():
            for call_id, call_info in calls.items():
                call_info['call_id'] = call_id
                call_info['location'] = location
                records.append(call_info)
    return pd.DataFrame(records)

# %%
calls_data = {}
for file_path in glob.glob('Week2/calls/*.json'):
    with open(file_path, 'r') as file:
        file_data = json.load(file
                              )
        for location, calls in file_data.items():
            if location in calls_data:
                calls_data[location].update(calls)  # Merge calls for this location
            else:
                calls_data[location] = calls  # Initialize calls for this location

calls_data
# Out:
# {'bangalore': {'c_0195b1db-9c43-4a1b-a0ab-241d46b65ccc': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '20962728',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'medium',
#    'commission': 705},
#   'c_82aa1a0f-5bf6-49a8-9a32-ceda4b0bea08': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '93884912',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_f26adcb6-1fbd-4c5d-a844-e861dd6088e7': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '34997608',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_a930dc43-76d4-43fe-a6c4-af82427c65b5': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '08890010',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_ee2e7e49-799b-48c0-a0fd-f89a02d7c463': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '41021032',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_2d6c1aa5-5c0e-4f9c-94d1-88cd55ea724f': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '38853841',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'easy',
#    'commission': 576.0},
#   'c_27937648-2bea-43fd-a36e-ec60f5a278ae': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '92007895',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_d0f0499c-85f2-4366-9dcb-8ec711c5a0cf': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '44485174',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_da015063-c57b-4b80-a691-e887f0193f2d': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '90711298',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_3429b3cd-9444-4778-9974-9e5eb653c5de': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '05020679',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_c107e0d2-c781-45c2-bf64-4df0ffb0b603': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '27164849',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_f93312f4-fe3e-43ac-8077-872575f88230': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '34706145',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'easy',
#    'commission': 576.0},
#   'c_42fde77b-0fc8-46c6-a165-1e832c0e512b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '13106054',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_63c9641d-53bf-46b8-95cf-4eccafbf2ba9': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '51730380',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_0a9d8125-fec8-42e2-a2e4-43d64b84907e': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '84519096',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_0c7b774c-1071-4649-8a57-5d05814acfe1': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '91326082',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_c2e1b361-91d9-403e-b50d-349e62a0a194': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '08070279',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_48b2f402-47cd-4118-98d0-d0f3799ad257': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '68601987',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_99f9c914-e87b-40a8-ac9f-c3f65509fc5b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '03197817',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'hard',
#    'commission': 834.0},
#   'c_01aca6d4-93ca-4300-a16e-7435f1a718d7': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '86512130',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_3b8fc6c5-1272-4040-8ab8-c7e7ffbf3b4b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '23271611',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_336ae3d0-ec88-4614-b7a0-a1b20caa2dae': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '53592772',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_156fa26a-6b4b-48d8-8999-79e45e2ec3c1': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '53533869',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'hard',
#    'commission': 882.0},
#   'c_e5f37f0a-fbd7-4e0c-a15a-1430810b43e9': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '78270729',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_a7b35cb5-5fec-4b62-a2ee-d430b8c63842': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '39935297',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_60e00350-87ad-4cb1-966c-a774884ffdc3': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '63535042',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_00108c8e-eb6b-4842-86a8-5912a516d6c9': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '21114648',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'easy',
#    'commission': 588.0},
#   'c_f5fa32ab-ef73-4b97-980e-fcc3c186d112': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '79188596',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_f864bd9f-3120-4033-b185-e9838fca65e3': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '46289588',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'hard',
#    'commission': 834.0},
#   'c_997e683e-14d2-4a9d-b0f1-7333f63cfdcb': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '72057402',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_434cc5e7-596d-4ac6-93fc-8e6da986ed5e': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '17175072',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_71a13ccb-f83f-40f4-991e-a8380d8b8b7b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '39569238',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_1601635e-fe16-48d1-89c6-57db7bca8ade': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '73334214',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_672dc971-599e-4d0f-bd03-d5d51662e9cc': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '35154175',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_63293081-8443-4e25-b2ec-46a9124f197a': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '94456020',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_dc12f120-1f5a-44b3-aaa0-5fd0ae797a00': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '24792243',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'medium',
#    'commission': 710},
#   'c_7d6582b5-e991-4bb2-8ce6-9ee61716bb5e': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '78630457',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_998ab5be-f239-4041-8b87-4a348e63a137': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '23174925',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'hard',
#    'commission': 900.0},
#   'c_1034597a-eb7a-4e00-8887-dd5a1b271b6e': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '26979885',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'medium',
#    'commission': 750},
#   'c_1468ad97-084a-4160-8b09-e4531bd1ab14': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '09145048',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_d2f6c240-f735-43c9-8673-0712b4e75dd0': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '97809493',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_433491a8-3662-4af7-adf0-92768da33446': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '37826650',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'hard',
#    'commission': 828.0},
#   'c_61e94d36-259f-4f83-81fd-adb4575f33db': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '55052247',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_0aa3f1e9-fe89-49b6-b883-0c3d145a0a4a': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '38278318',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'hard',
#    'commission': 828.0},
#   'c_d5b7742c-26dd-44be-8904-c7ae8f1d6f09': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '21670435',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_21d87f90-84b0-46cd-80d7-74794a1163bc': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '93903914',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_8202992a-8a1b-4a40-b57a-2220fbf81e63': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '80775120',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'medium',
#    'commission': 750},
#   'c_c3e1323d-cabc-436c-a0ad-ba7adac8d3a3': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '17475867',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'medium',
#    'commission': 710},
#   'c_3a7e256f-7852-4f1e-bcbf-be4a6a22d9ae': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '81350458',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_43f2b7e0-faa7-4774-a7bb-c7974d7ecb98': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '64457177',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_f0b6d1fe-443c-4731-a70e-b8bbdb7b467e': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '02134400',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_1411a7c5-285d-40db-8d65-87fd4aadf68f': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '40566541',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_8c2a8d82-c41a-4bc8-af9d-bed2d10f5c23': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '84863627',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_ed8cdf26-700c-4711-b747-f37efe86d49f': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '08167484',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'medium',
#    'commission': 710},
#   'c_6712365b-d06b-41fe-952f-bc859ec3f275': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '89359298',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_bbf3c8c7-5bd8-42f3-8192-53486065248f': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '38611476',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_0e6930aa-e313-4548-bdea-45d257be9ac1': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '24388838',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_9bd913c8-9a0a-41b1-bfc2-2fce9329fecf': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '46374804',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'easy',
#    'commission': 588.0},
#   'c_46231e4a-3cc4-4045-b80c-2e370fd52b96': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '35877760',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_0af7109f-2d3e-4b90-9429-29814848e45c': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '69139054',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_447b67a9-2eaa-49a6-8ccd-3d8c9a162273': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '14645496',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_aae57a38-1239-45f7-bb45-f3b8bde0914a': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '56495036',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'medium',
#    'commission': 750},
#   'c_a3f6b547-6093-4b9f-b9f1-1355c601aeae': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '77237835',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_5e6cfa82-2ddb-40b3-802f-23320e8420d8': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '11352686',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_99056817-e8bc-4fb5-8724-6a447cf9d62d': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '86432391',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'medium',
#    'commission': 705},
#   'c_924b50c7-3a3a-41fe-9e7a-35337e5554c6': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '23487083',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_e422e935-b203-4222-8421-fc5d4a5465bf': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '88895420',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_e9bc5b80-8d19-41de-a662-7cca48a3b95c': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '35056127',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_ad7c356a-87ac-42c6-bf2e-8f95ca9316a5': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '28720765',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'hard',
#    'commission': 882.0},
#   'c_1bb752d2-2e03-45f7-9838-4d8fd8e48e69': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '58774686',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_1343186f-5590-4e6e-bdd7-5915c20218eb': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '07544632',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_6b831f76-2092-49a7-9c71-5dab5c9418d0': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '80455926',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'easy',
#    'commission': 564.0},
#   'c_77040bf9-51bd-44f9-b738-e1ec4e64e474': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '34391910',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_eff87077-981b-4a44-b211-3acfbe3d1930': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '40704064',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_b7033ecd-925c-405f-96b4-5fb1b53bc898': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '46317437',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_ec7aed07-1a04-4c71-b641-7abaf99560f4': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '70343570',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_d6e33eaf-94a3-4bca-a952-a91901d6017a': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '31882425',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_1cc0ef8a-4014-46ea-a8a5-9fb2d2b996bf': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '06553175',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_c17ee3d5-cc32-4597-9c68-12146e9b933e': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '70149897',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'easy',
#    'commission': 576.0},
#   'c_89a5a96b-ab4c-49fc-90ed-0a7a27a4456b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '82013576',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'hard',
#    'commission': 864.0},
#   'c_426e1c09-0ed8-445f-9b5a-aa09edb9c8f8': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '73867137',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_589476b1-3605-4def-b95b-57b6f471efbe': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '38256812',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_e70fd8d0-e621-4d27-a623-50f337c64c16': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '04403562',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_a9a6b2b8-f30d-4c20-b508-fc36ab33c636': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '04517794',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'medium',
#    'commission': 710},
#   'c_ba47d391-7ce6-4653-b839-df63a156031c': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '54227342',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_cb0063b3-3e69-41d8-ac76-86ffce7c6933': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '86979548',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_bc082602-979a-4955-a0d5-669a8da31ec4': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '79366890',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'medium',
#    'commission': 665},
#   'c_c528e91d-4724-4630-9591-7e98fd25b200': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '08106586',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_7a79f6b5-0c6e-4263-b3c4-0cd4f347363d': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '41531052',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'hard',
#    'commission': 882.0},
#   'c_855b1653-64c1-4dcc-9c85-7e092ec8a2ce': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '59580787',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_b60a9cf5-b530-4a91-972a-d27223e542d8': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '86531920',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'hard',
#    'commission': 864.0},
#   'c_d603821d-06a9-41b8-a050-274038e90800': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '98128284',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_296fd3ea-85ab-4f23-a700-4faaf30fe6a8': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '09286367',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_6c4cf579-9468-49d8-a288-93df5ac82258': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '01803871',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_7f7dc7ed-0d23-4d92-aa7b-b20e8c01e9d9': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '29436629',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_8a6a7298-0516-43aa-8304-4a0ad7283cb2': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '54397951',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_30289fd4-fbc1-47d6-9f71-eb09f298a7a6': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '58592887',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'hard',
#    'commission': 828.0},
#   'c_573bf4d8-ac6c-4c1e-b9d1-0ea3d67f19fe': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '57704328',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_7b609497-1b76-43e9-ad14-c5df23db7905': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '87691649',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_4ec91b24-5a96-4dde-a808-94f03561bb9a': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '02947245',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_f6a989db-bada-4c81-a5b7-2ba6b966b511': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '84367069',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_f5dc0f10-74e9-4d0c-9e41-48416f4f3f00': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '38083716',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_93d25120-8fab-47e7-a48d-78824d348d19': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '28035704',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_f36460af-3056-423a-bb28-e609e1a026af': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '45300525',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_a32ef110-8759-4313-8ab7-bfd0338c36d1': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '35700466',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'hard',
#    'commission': 882.0},
#   'c_d0fa2534-b61b-4f83-a6f6-b19197282ed7': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '76882269',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'easy',
#    'commission': 576.0},
#   'c_3c6401f4-b408-4f00-ab8f-513b72304c6a': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '67052915',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_918dc00a-f2a3-4ad2-810f-02b282883ede': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '93689388',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_bdb425c1-6e30-459d-ab19-932777cf4179': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '85198592',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_19f3b838-dcb2-4c79-80da-bbe3d5c844bd': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '45843631',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_2b2e6dcd-10d9-4230-bf86-ec1ee26fa8ea': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '81448165',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_41d96582-5f28-4a57-acd8-1d515a73e92f': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '06527148',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'medium',
#    'commission': 705},
#   'c_d0fa4835-01e8-4e34-beab-694c902115bf': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '73388579',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_84901673-2a12-4c95-b9d8-2a5b2f054767': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '64913796',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'hard',
#    'commission': 864.0},
#   'c_1ba9ab57-dba5-48f9-a0f5-97b026fc55d6': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '61320499',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_41706c1a-084e-46bf-bb9a-8d95269247bb': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '09550736',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'hard',
#    'commission': 900.0},
#   'c_e4fb0452-bcec-4dbf-a4bf-f433b4b71c4e': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '04820879',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'hard',
#    'commission': 864.0},
#   'c_b6c45432-3795-4831-a953-3e800b229a4b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '19598775',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'medium',
#    'commission': 705},
#   'c_a546da9b-cf97-4959-bd5d-724b0e50f57b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '55554739',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_badb0ff7-38c2-4c51-9411-12d4dc7cf858': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '66518185',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_4971b0f5-298d-431a-88cb-c4f47b0b204a': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '61179233',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'easy',
#    'commission': 564.0},
#   'c_c3394dd4-9b10-450f-9d44-27445efab705': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '85781447',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_1d7e2a73-122f-40e2-a71d-2ee2d98b9453': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '08501070',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'medium',
#    'commission': 665},
#   'c_92e29d2a-1157-4035-a3d8-bfb5b9ec13cb': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '06622515',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_6123d4c4-a53c-42b8-8ebb-791b0a42eb2d': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '10033036',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_bf123d40-7380-4d76-85de-c49ffd9b252e': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '86995307',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'medium',
#    'commission': 665},
#   'c_e65efa2a-0e3d-47ab-9855-c14486738247': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '61071263',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'easy',
#    'commission': 588.0},
#   'c_d6eabeda-ec71-489e-abfc-de297cefeb3d': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '25599381',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'hard',
#    'commission': 864.0},
#   'c_3b3794d7-9565-4a10-b164-14784880fa60': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '24841073',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_c0d743f8-08e9-41d2-b5d3-f8930f22da7d': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '39480667',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_d66c9a37-1a07-49c3-9d6c-5d12885fb103': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '68884712',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_fa64dd76-396b-4e89-ad3e-d970437f9583': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '34418379',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_d66c886a-5a8a-4214-9695-1051e30a953f': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '18411443',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'medium',
#    'commission': 705},
#   'c_71a96012-2c1b-467e-8a77-c1311b06b4a3': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '79469427',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_d0734c3f-0f50-4029-94d7-39953a8b944f': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '38598500',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_614e6dfa-1b23-43d9-8885-a35994e89919': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '80791431',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'easy',
#    'commission': 588.0},
#   'c_8f648fdc-79f3-4733-bcb9-9882a601a272': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '64965812',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'easy',
#    'commission': 588.0},
#   'c_d13ce32d-dea1-47a1-97e0-cedca8352c6b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '60413523',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'medium',
#    'commission': 750},
#   'c_0b37a12d-7a94-476e-986e-c06b8846e4ce': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '95091138',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'hard',
#    'commission': 864.0},
#   'c_ce34641f-0650-4dd0-a45c-1cf34ce89133': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '35594931',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'medium',
#    'commission': 750},
#   'c_eb8d43b4-64d5-4b8b-bf40-bb2e2c576ba8': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '03352935',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'easy',
#    'commission': 588.0},
#   'c_e47b6f33-f897-4cda-af4f-b57c8f9723b7': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '41524558',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'medium',
#    'commission': 750},
#   'c_1eaaaf83-1bfd-4d6b-b345-f07fe0d5de11': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '15015709',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'easy',
#    'commission': 564.0},
#   'c_1eb1fefb-36c1-4d51-95ab-0c1736532745': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '60951330',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_f0b3c836-8aa0-4f7b-8a96-94a89a3c6ba6': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '14692482',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_5eb14659-475b-4d67-97eb-80639fe5a0d5': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '40365715',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_a502f4e1-5c36-48d2-860e-14bed9a9643a': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '60684039',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'easy',
#    'commission': 564.0},
#   'c_c3019e5a-54ce-4694-a080-1454edd68ae6': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '86308075',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_38cd6092-9ab1-4a36-9ea4-63751172adea': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '60050526',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'hard',
#    'commission': 828.0},
#   'c_a5ca0bbc-ecd5-44a2-8613-28b68252e6a7': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '00506915',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'hard',
#    'commission': 900.0},
#   'c_2e5c850a-25d7-48f5-b650-ef8054c238c9': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '05994512',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'hard',
#    'commission': 828.0},
#   'c_7c343453-362d-49dc-aa03-44eab37a8805': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '00345551',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'medium',
#    'commission': 710},
#   'c_c9b3f7f3-7ad0-4bbe-ada1-2d420c73f4cc': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '92444138',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_ba09526b-31e3-44e3-b742-f6408361a0be': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '84400183',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_cf015bea-77f5-478c-81c4-168e98ac0a35': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '73167173',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_617f3cce-f3dd-405d-b3ec-469c3796bd88': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '26119756',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_38f8fa45-6696-40c2-8603-c823fc5f91e1': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '39629313',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_b19be56c-43e3-419f-910d-1d62d8a85bb9': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '09487275',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_a68e9b3d-7c91-4d3a-8054-cb67e530dbd8': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '83999018',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_2fb19c83-473e-4df3-bdc8-8fd47e601c73': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '16063156',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'medium',
#    'commission': 750},
#   'c_6ba757fc-827b-4028-9efa-9d7643882893': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '78085893',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_6d90a39e-f5f9-46fb-a6c6-264f9154fc5b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '54443626',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'hard',
#    'commission': 882.0},
#   'c_5d644ced-6f0f-45de-a8ae-ecc9a60308af': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '17424045',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_0c42c500-9b84-4ecf-a7bd-b6753d2f6ad7': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '22746977',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'hard',
#    'commission': 864.0},
#   'c_82763260-1cc1-489d-b801-760e56899957': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '29842817',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_eb7b0174-ef55-4949-9db1-44b2bf145579': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '75705199',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_7aed83fb-b684-45c3-b678-fac958320e16': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '90792499',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_c82bbf07-1ae6-4ec8-9d4b-e0130494926f': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '97771300',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_f24b8b63-a775-4662-a32c-912671aeadfb': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '97694546',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_1ac70d05-41e4-4bca-95d4-7f0e64089ca1': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '07112553',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_51a1b6f9-f6da-47db-ba20-f2b7027be71e': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '96692436',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_afa3947b-839f-43d1-9ca2-ae3be57dfcce': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '05787657',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'hard',
#    'commission': 882.0},
#   'c_d3515b7e-d7a2-4fa1-af35-ccef68fb54ea': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '15878951',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_c1854d18-ded9-40e0-891f-096cf84c3591': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '70186456',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'easy',
#    'commission': 576.0},
#   'c_4dcf5878-de87-43a8-ba24-5149f6dfdf54': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '01454136',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_05c24af0-d28c-4a4d-9b16-a89ac726a0fb': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '84082523',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_72181844-d487-4088-abde-f13291ce7eb9': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '81411261',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_1acf7af0-ddc5-481e-ad36-1e6ade3c736d': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '93766916',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'hard',
#    'commission': 900.0},
#   'c_2fb29631-be21-4893-99ab-298e22ce68ee': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '11616439',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_bce0a882-436b-4eb6-bac3-60e6f472708b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '14219956',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_8936d9eb-704f-4ee8-8d1b-8dfc3316f3e8': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '39400820',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_3cd49c14-97b3-4145-b093-cb8f6961ae9a': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '25424604',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_175324ec-f75a-4ba5-9b3e-cc87ebc68de3': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '41068143',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'medium',
#    'commission': 710},
#   'c_50d8720e-7799-4815-a1eb-59969e5088d2': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '43101359',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_23c62d8e-2055-4770-800d-9886d8410031': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '15693546',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_c3ef52fa-2a8a-4f58-8385-77663177da89': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '27231184',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_f0a9b521-951e-4f8c-af0a-6d1b15772167': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '51646001',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_88dc8e48-03c7-4ce0-a780-98bd651b26f7': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '59047447',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'medium',
#    'commission': 750},
#   'c_53e02ae3-ffd0-4ad8-ae23-121e57ac8314': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '85833816',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_966c9bbf-6eb7-4283-aec9-677eed73aabf': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '63970229',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_3fc40d03-94a3-4ed3-8982-88e291e30675': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '02200720',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_12606090-3dde-409a-858e-596eebea4470': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '21340482',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_4c466f10-726e-4c24-adf7-7c84e5b42c1f': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '47787102',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'medium',
#    'commission': 705},
#   'c_a6315a30-6bcb-4b18-8b73-eab803ef4d79': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '56203407',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_97c47b07-123e-448f-9d95-e929aeb71cb3': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '03985441',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'easy',
#    'commission': 576.0},
#   'c_0a5ec8fa-2bcc-4aba-a054-d35a9865aa60': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '17083146',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'hard',
#    'commission': 882.0},
#   'c_85b48693-111a-4a2c-9fc8-686f3e3fd1d7': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '91926659',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'hard',
#    'commission': 900.0},
#   'c_69afe97d-7e8a-43d3-97fa-db22476987e8': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '56193623',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_f5d149f2-f146-4431-a0f7-b92b86cf3455': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '45679709',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'medium',
#    'commission': 750},
#   'c_a4df4453-c896-42a7-8b4a-cadb72dbbf22': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '49849404',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_16b43d61-91ea-495e-91ef-1ba2ee082c85': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '48089055',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_7bccd1c5-f807-42a9-86b5-405346e640dc': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '00819114',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_d97d2475-655b-44bf-8ae6-bff7699427f1': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '65308295',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_5945b313-960e-45b0-a79c-ff1361605ef6': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '27188680',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_b5daaf19-acb0-4b98-85e8-f27f0638d3b9': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '59966051',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_9afaf744-2e49-4032-a1d8-e58c28c09b1f': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '87054761',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_42ca8984-6e7c-4046-9d42-294a6630085d': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '01086085',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_f13a5035-3381-434f-8541-f55527a43fca': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '56972571',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_0853a6e7-fcc7-47d9-9130-825aa0677af6': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '78353616',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_9f553a8d-f758-49e8-bb80-5598d9fe6471': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '52383696',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'hard',
#    'commission': 900.0},
#   'c_1babafba-0746-4b8c-8624-24cc14ac4816': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '21527432',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_79e55804-0a82-4fa6-80c2-69eec386a91a': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '87716537',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_40ece1ea-63b0-4293-9029-90e1f602bc06': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '68529017',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_a8ff6811-d209-4e05-8566-be8a1c33f010': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '63432434',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_3d5d6acd-58e0-40b0-9e9b-1576eccdf759': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '70372982',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_df866c64-c300-49cc-83bf-86e8c6c471ac': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '29185310',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_864fcb7e-32d4-444d-9cea-a4009cda37ea': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '80345101',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_1258e682-37c6-4277-a225-1027d4af4ec3': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '52635513',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'hard',
#    'commission': 864.0},
#   'c_43908856-d280-452a-9799-2a22935830d0': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '23530275',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_61422e65-9238-4a1b-bd7e-c5ae1c233d33': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '08699049',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_3fed5c16-6e6d-443e-b017-a7aece201c6d': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '42618413',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'hard',
#    'commission': 900.0},
#   'c_1eec037a-eb11-45a2-b5d0-a96808806989': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '85140265',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_361107bd-2a69-429e-9d34-e4069dbb74a4': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '66590844',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_11c0a0bf-22c4-4721-8f64-ae0c3661eead': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '36741937',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'easy',
#    'commission': 576.0},
# ...
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_1d755b0b-410a-4f6f-a641-e6d37fab01cf': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '71927964',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_903f8356-137f-4fdc-8cef-504907ba759d': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '16440856',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_4d8703b5-3f62-4f15-9e77-ae95c89098b7': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '12358505',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_7bdc8fc3-d6d9-4048-8eb3-dac288de353a': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '06168625',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_827ca7d0-a036-4d90-877d-e14bb143af53': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '27642242',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_58bdb079-eb2c-465b-b5e5-ef48ea697ace': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '80297081',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'hard',
#    'commission': 882.0},
#   'c_2d37a989-69f4-4265-8ad1-7e52d8a7ecf3': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '80442706',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_3d6b1307-de13-45b4-8bd2-40fe7cc76064': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '59352290',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_14b0babf-0752-450b-98b3-e0da987d0548': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '81589531',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'hard',
#    'commission': 828.0},
#   'c_6e002a99-65c6-4ff3-85db-025af9c3dd17': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '94730868',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'easy',
#    'commission': 560.0},
#   'c_593b2cda-6742-4e0d-9d7a-15387399f873': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '08563535',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_2974d0c2-1082-4971-b976-f20a097dda05': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '86222855',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'easy',
#    'commission': 560.0},
#   'c_be2f8dc1-83e5-4304-9624-ab4117797755': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '79388758',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_dfbcf503-6047-4f8d-8eac-9109432330a5': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '91234493',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_40e246c1-731a-4b96-80c6-0c1d9414cc85': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '85204652',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_0ea6cc70-0cc2-42fe-b748-5023517ed5be': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '31450481',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_37628e4d-36a8-4ac6-90d7-485af0b35720': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '89546210',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_29f378c9-d34c-4d4a-8026-dd88cfb5966b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '82226167',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'medium',
#    'commission': 710},
#   'c_f9349c8b-59a3-4d8a-aa15-ce188a757faa': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '67516849',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_01ef5a49-31b4-4c9d-b1d4-83b7f7b1c74e': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '57557611',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'easy',
#    'commission': 588.0},
#   'c_ade76693-ca28-465a-ab00-ced05f36ab72': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '23665624',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_8beb6282-1547-461c-9f69-1fe202a501e8': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '82140351',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'hard',
#    'commission': 834.0},
#   'c_d42cf39d-511d-4b8a-9aff-ecb13c0d092c': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '98945406',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_f6927d51-ecf2-4ed4-8fbd-064b534f3f0b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '70094780',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'easy',
#    'commission': 564.0},
#   'c_7060de92-8a4a-4695-b268-223118e45de9': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '84620089',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'easy',
#    'commission': 560.0},
#   'c_85640678-3b1d-4d77-9e63-55f510f5d479': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '62078594',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'medium',
#    'commission': 665},
#   'c_6b01781a-94c1-4f2f-9ee5-fb8eea8420ef': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '25365650',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_ef0d8f19-1e0f-495d-8de5-5e23ffdad931': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '28330861',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'hard',
#    'commission': 828.0},
#   'c_d1edbf30-af9b-482e-aff4-978e5779f760': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '78584964',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'hard',
#    'commission': 828.0},
#   'c_5a05236f-42ba-46e5-8e88-73d9a81bab00': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '91285254',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'easy',
#    'commission': 564.0},
#   'c_ab093371-1001-4e75-8b6c-a34396d10884': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '27586626',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_3c39f736-c84e-47e5-b2de-14b1ac7a6eeb': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '11507630',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'easy',
#    'commission': 576.0},
#   'c_d56d5805-89c7-45c9-9a1c-ced29d679a9d': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '91463231',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_97babee2-6606-46d1-87bf-979b3c9768a8': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '41505316',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_7f9ed4ed-50f8-43d8-9b36-194a896ed318': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '56362525',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_50ae879b-8936-4dec-89c8-4b06e48a16f7': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '18481336',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_f3038f5e-d706-45d0-af38-7330ab2dbeae': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '02500430',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_c19f298a-e7bf-4fe3-bf19-482ac864d3f6': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '10034971',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_656a5337-d603-4b58-9d37-b57b7b1d4dbf': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '00661080',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'easy',
#    'commission': 564.0},
#   'c_b42b7659-f867-4518-bfe2-cc2b2a104b77': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '86714683',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_e10f5cfe-62d0-4384-b9c4-16e0650ed043': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '54799694',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_b19f18c0-f3a5-4275-873e-30719e9a91cc': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '63116305',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_efaa7da0-6391-4dbf-8d9e-532e1e5926c9': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '26897937',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_ee8b1931-3ae8-4be4-a17d-8cbe90d3a641': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '07300226',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'medium',
#    'commission': 710},
#   'c_034cd27e-9842-4860-9a5a-defa8d0fe5d3': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '58046125',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_e0a4dcd7-e5d9-4a5d-9666-b7d71c691302': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '45097295',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'hard',
#    'commission': 828.0},
#   'c_2e27b578-5b3b-45f9-a975-a50f1fde6c0d': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '27904457',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_72213283-5df1-4b22-b45d-fa2ce3de8143': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '56592582',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_cd17ce83-64a6-42da-8232-bd916c1fceea': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '98354918',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_39d52833-357b-499a-bf35-5cce16555403': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '95650350',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'easy',
#    'commission': 576.0},
#   'c_d8b33af6-cfab-4b5d-89bc-530ddb565a2b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '63814303',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'hard',
#    'commission': 900.0},
#   'c_9d58d461-ca79-4dc2-8e05-48e348480c18': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '27266683',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_fbc6f2d0-75cf-42d3-83fb-9d430118058c': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '71338059',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_de883b0d-068a-4f50-aeed-773f0b775c58': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '97527736',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_5fb66384-98c6-4bd7-86ea-6657f39d7362': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '75580622',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_9c37389c-0d12-4b46-be35-5d2fdcf7d5ab': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '72331151',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_b15f3bdb-50f3-4db6-848c-84223e1a7560': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '28323866',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'hard',
#    'commission': 864.0},
#   'c_5988e0e3-d6fc-4164-84ad-c86327fbbd7b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '96321143',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_acd08f7a-2f20-4729-9332-9798fc9f9c1e': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '94797593',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'easy',
#    'commission': 564.0},
#   'c_188773f9-84bf-47be-b189-2b001b722f4c': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '15330450',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_3a142f84-a7e5-4870-b90e-4e66eb50f14b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '57590730',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_15608227-0911-4c93-b327-2b6b063ef302': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '62342669',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_6879d3f6-90f4-4e26-b929-2a275a12bb10': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '21954367',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_de7e3258-c3fc-4348-9a02-c8a606f21d9f': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '22008212',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'easy',
#    'commission': 576.0},
#   'c_bb5f5b73-0cb0-44b3-a6f4-48f1795e090b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '56175379',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'hard',
#    'commission': 882.0},
#   'c_9dea2de5-e3b0-4285-940d-0151d0507584': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '90688154',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'easy',
#    'commission': 588.0},
#   'c_891e96c8-a7df-429c-ac8b-e74d74fbf6b7': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '31381439',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_9c6c1067-d5ea-499d-a0c6-7e4675841955': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '13145227',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_e5e9e325-c52f-498c-82d4-6c641978d4f3': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '77019866',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_77a22857-642f-4957-b148-cb2a95487477': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '59586637',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_53662a5b-c512-4e37-9c27-84b5e5bd1ca3': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '09476125',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_de76b99d-7e0d-4ab9-8920-353572dc281b': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '72123544',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_4cd3f241-3b30-4072-b742-7fcb5d03bb57': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '10170849',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_341a583b-027b-42e3-9dc1-8a9f28b0cf77': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '69399487',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'easy',
#    'commission': 564.0},
#   'c_f39dffc9-76ca-4ed2-b068-365a62014065': {'date': '1970-01-01 00:00:00+00:00',
#    'tlf_number': '03970852',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'easy',
#    'commission': 588.0},
#   ...}}

# %%
# Load feature calls, previous calls, previous reports, and schedules
future_calls_df = load_and_flatten_data('Week3/calls', 'call_id')
previous_calls_df = load_and_flatten_data('Week2/calls', 'call_id')
previous_calls_df
# Out:
#                              date tlf_number  \
# 0       1970-01-01 00:00:00+00:00   20962728
# 1       1970-01-01 00:00:00+00:00   93884912
# 2       1970-01-01 00:00:00+00:00   34997608
# 3       1970-01-01 00:00:00+00:00   08890010
# 4       1970-01-01 00:00:00+00:00   41021032
# ...                           ...        ...
# 260288  1970-01-01 00:00:00+00:00   21482224
# 260289  1970-01-01 00:00:00+00:00   54350588
# 260290  1970-01-01 00:00:00+00:00   78885138
# 260291  1970-01-01 00:00:00+00:00   48763576
# 260292  1970-01-01 00:00:00+00:00   57423650
#
#                               technical_problem difficulty  commission  \
# 0                   device_and_peripheral_setup     medium       705.0
# 1                   device_and_peripheral_setup       hard       846.0
# 2                          email_related_issues     medium       700.0
# 3       software_installation_and_configuration       easy       600.0
# 4                             internet_problems       hard       816.0
# ...                                         ...        ...         ...
# 260288                     email_related_issues       easy       560.0
# 260289            browser_and_web_based_support       easy       520.0
# 260290  software_installation_and_configuration       easy       600.0
# 260291                           teams_problems       hard       798.0
# 260292                            zoom_problems       easy       556.0
#
#                                        call_id   location
# 0       c_0195b1db-9c43-4a1b-a0ab-241d46b65ccc  bangalore
# 1       c_82aa1a0f-5bf6-49a8-9a32-ceda4b0bea08  bangalore
# 2       c_f26adcb6-1fbd-4c5d-a844-e861dd6088e7  bangalore
# 3       c_a930dc43-76d4-43fe-a6c4-af82427c65b5  bangalore
# 4       c_ee2e7e49-799b-48c0-a0fd-f89a02d7c463  bangalore
# ...                                        ...        ...
# 260288  c_592e71fd-a512-4a6d-ac83-46779c378d42  hyderabad
# 260289  c_fe0eb66a-f7de-4db0-b421-f98b6a1e387c  hyderabad
# 260290  c_4e7ca62b-18d8-45fa-918c-b3da7fa5436b  hyderabad
# 260291  c_fc9f040e-99f1-4785-8fbd-e261632d5ae2  hyderabad
# 260292  c_93ad8b97-7a5e-450f-adae-c8c42797381e  hyderabad
#
# [260293 rows x 7 columns]

# %%
future_calls_df
# Out:
#                              date tlf_number  \
# 0       1970-01-01 00:00:00+00:00   30134029
# 1       1970-01-01 00:00:00+00:00   60496609
# 2       1970-01-01 00:00:00+00:00   91681812
# 3       1970-01-01 00:00:00+00:00   04938996
# 4       1970-01-01 00:00:00+00:00   59536017
# ...                           ...        ...
# 260052  1970-01-01 00:00:00+00:00   60822405
# 260053  1970-01-01 00:00:00+00:00   62836494
# 260054  1970-01-01 00:00:00+00:00   17220135
# 260055  1970-01-01 00:00:00+00:00   47242825
# 260056  1970-01-01 00:00:00+00:00   36614859
#
#                               technical_problem difficulty  commission  \
# 0                basic_hardware_troubleshooting       hard       864.0
# 1       software_installation_and_configuration       hard       900.0
# 2                      operating_system_support       hard       882.0
# 3                                 zoom_problems       hard       834.0
# 4       software_installation_and_configuration       easy       600.0
# ...                                         ...        ...         ...
# 260052              account_and_security_issues     medium       710.0
# 260053                 operating_system_support       easy       588.0
# 260054                           teams_problems       easy       532.0
# 260055                            zoom_problems       hard       834.0
# 260056                 operating_system_support       hard       882.0
#
#                                        call_id   location
# 0       c_3d390740-68df-4579-b437-fcd1a25b0ca8  bangalore
# 1       c_80affc8f-bf2c-4c0f-9460-9c95b2e007fa  bangalore
# 2       c_b3278b67-74c0-42d0-9007-5b62e2f0c72e  bangalore
# 3       c_d93e9286-1775-4e83-9711-17fa8011be6d  bangalore
# 4       c_a7598d3e-8046-4fff-91e5-9b3eb6c52ed2  bangalore
# ...                                        ...        ...
# 260052  c_089dc1ec-ca09-4d9c-82eb-9a4a1802fe23  hyderabad
# 260053  c_984b60ae-efed-4533-b6b2-4dcaf9cf551b  hyderabad
# 260054  c_2e9a9bef-b496-4c12-9cdb-9646547d0954  hyderabad
# 260055  c_cd0f66f1-52df-40f4-b1d2-5d26b92183f6  hyderabad
# 260056  c_ecf37140-4ff9-4a2a-ab09-fab0f0a7e587  hyderabad
#
# [260057 rows x 7 columns]

# %%
# Load previous and new reports
previous_reports = []
for file_path in glob.glob('Week2/call_report_week2/*.json'):
    previous_reports.extend(pd.read_json(file_path).to_dict(orient='records'))
previous_reports_df = pd.DataFrame(previous_reports)
previous_reports_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Load previous and new reports
#       2 previous_reports = []
# ----> 3 for file_path in glob.glob('Week2/call_report_week2/*.json'):
#       4     previous_reports.extend(pd.read_json(file_path).to_dict(orient='records'))
#       5 previous_reports_df = pd.DataFrame(previous_reports)
#
# NameError: name 'glob' is not defined

# %%
new_reports = []
for file_path in glob.glob('Week2\call_report_week2/*.json'):
    new_reports.extend(pd.read_json(file_path).to_dict(orient='records'))
new_reports_df = pd.DataFrame(new_reports)

# %%
new_reports_df
# Out:
#                                       call_id  \
# 0      c_0195b1db-9c43-4a1b-a0ab-241d46b65ccc
# 1      c_1cc0ef8a-4014-46ea-a8a5-9fb2d2b996bf
# 2      c_cf015bea-77f5-478c-81c4-168e98ac0a35
# 3      c_f7786fe6-39e3-47c5-8539-f7e716189ef4
# 4      c_edc1511a-d8af-4984-be9c-28bed6dfae93
# ...                                       ...
# 67138  c_33239abc-6fd2-44b4-bb54-1c5d45c1644f
# 67139  c_9b38a1a3-a837-4590-9577-42edaf0ccd3a
# 67140  c_2659df8a-b775-4904-8d45-cf8e9cf0a009
# 67141  c_f9ac151b-9bcc-4327-99cd-7468bcecfa0d
# 67142  c_0d6ccd3b-1059-4819-aae3-8174a52f308e
#
#                                     worker_id  call_time  likely_to_recommend  \
# 0      w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960  45.522797                  1.0
# 1      w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960  30.887813                  1.0
# 2      w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960  64.506471                  1.0
# 3      w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960  64.682155                  1.0
# 4      w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960  15.946662                  7.6
# ...                                       ...        ...                  ...
# 67138  w_f5400776-c6cc-4563-b835-b5ee56242aa1  15.521120                 10.0
# 67139  w_f5400776-c6cc-4563-b835-b5ee56242aa1  15.965120                  9.8
# 67140  w_f5400776-c6cc-4563-b835-b5ee56242aa1  15.867863                  8.5
# 67141  w_f5400776-c6cc-4563-b835-b5ee56242aa1  29.894669                  4.9
# 67142  w_f5400776-c6cc-4563-b835-b5ee56242aa1  21.363210                  6.2
#
#        professional_score  call_profit
# 0                     NaN          705
# 1                     NaN          520
# 2                     NaN          840
# 3                     NaN          834
# 4                     NaN          600
# ...                   ...          ...
# 67138                 NaN          552
# 67139                 NaN          690
# 67140                 NaN          564
# 67141                 NaN          700
# 67142                 NaN          520
#
# [67143 rows x 6 columns]

# %%
previous_reports_df
# Out:
#                                       call_id  \
# 0      c_a317abc5-a7e1-40c3-b486-c4eefdf8be05
# 1      c_256844cb-b710-4da7-8f95-238a7fdd5261
# 2      c_46bfdc38-5130-4e08-9918-4851d84930ce
# 3      c_497ac5ca-8ff3-4773-968c-2e300486c35d
# 4      c_97384374-b420-4259-aaa9-f2e1571928cb
# ...                                       ...
# 72511  c_282338ea-b4a3-4d55-801c-1935c08be259
# 72512  c_9f076c7e-aa1f-44e2-a904-ec7daaec52c4
# 72513  c_bece22d1-0ba0-4208-91f8-366c8267177c
# 72514  c_ac55b479-d0ad-4c68-a637-87b3c360ceb9
# 72515  c_5a9ca763-3a01-491b-9288-e4e17fce0abb
#
#                                     worker_id  call_time  likely_to_recommend  \
# 0      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  57.057332                  1.0
# 1      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  69.294334                  1.0
# 2      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  70.794334                  1.0
# 3      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  54.379299                  1.0
# 4      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  77.457332                  1.0
# ...                                       ...        ...                  ...
# 72511  w_ff6501e8-b49a-4512-a9eb-e06565d21355  37.453295                  1.0
# 72512  w_ff6501e8-b49a-4512-a9eb-e06565d21355  62.093346                  1.0
# 72513  w_ff6501e8-b49a-4512-a9eb-e06565d21355  61.482360                  1.0
# 72514  w_ff6501e8-b49a-4512-a9eb-e06565d21355  32.353295                  1.0
# 72515  w_ff6501e8-b49a-4512-a9eb-e06565d21355  57.151490                  1.0
#
#        professional_score  call_profit
# 0                     NaN          695
# 1                     NaN          735
# 2                     NaN          735
# 3                     NaN          532
# 4                     NaN          834
# ...                   ...          ...
# 72511                 NaN          705
# 72512                 NaN          780
# 72513                 NaN          864
# 72514                 NaN          564
# 72515                 NaN          690
#
# [72516 rows x 6 columns]

# %%
# Combine prices with calls based on technical problems
future_calls_df = future_calls_df.merge(prices_df, on='technical_problem', how='left')
previous_calls_df = previous_calls_df.merge(prices_df, on='technical_problem', how='left')

# %%
# Load previous schedules
schedule_records = []
for file_path in glob.glob('extracted/previous_schedules/*.json'):
    with open(file_path) as f:
        schedules_data = json.load(f)
    for worker_id, calls in schedules_data.items():
        for call_id in calls:
            schedule_records.append({'worker_id': worker_id, 'call_id': call_id})
previous_schedules_df = pd.DataFrame(schedule_records)

# %%
previous_schedules_df
# Out:
#                                      worker_id  \
# 0       w_3cbcf16f-2173-4281-bad0-b5579ba0f123
# 1       w_3cbcf16f-2173-4281-bad0-b5579ba0f123
# 2       w_3cbcf16f-2173-4281-bad0-b5579ba0f123
# 3       w_3cbcf16f-2173-4281-bad0-b5579ba0f123
# 4       w_3cbcf16f-2173-4281-bad0-b5579ba0f123
# ...                                        ...
# 283110  w_ff6501e8-b49a-4512-a9eb-e06565d21355
# 283111  w_ff6501e8-b49a-4512-a9eb-e06565d21355
# 283112  w_ff6501e8-b49a-4512-a9eb-e06565d21355
# 283113  w_ff6501e8-b49a-4512-a9eb-e06565d21355
# 283114  w_ff6501e8-b49a-4512-a9eb-e06565d21355
#
#                                        call_id
# 0       c_a317abc5-a7e1-40c3-b486-c4eefdf8be05
# 1       c_256844cb-b710-4da7-8f95-238a7fdd5261
# 2       c_46bfdc38-5130-4e08-9918-4851d84930ce
# 3       c_497ac5ca-8ff3-4773-968c-2e300486c35d
# 4       c_97384374-b420-4259-aaa9-f2e1571928cb
# ...                                        ...
# 283110  c_bf99f2ec-a582-4123-8b11-28d6a1c39551
# 283111  c_31d6c622-ad70-4772-908c-99768c628e43
# 283112  c_9b26aba2-542f-4ba4-931a-1feb8ffacb8f
# 283113  c_541e5944-02c7-4297-a66a-6f5949bd2688
# 283114  c_13546f61-61c9-483e-b941-c6f3c100a5a9
#
# [283115 rows x 2 columns]

# %%
# Load future schedules
future_schedules = []
for file_path in glob.glob('Week2\call_schedule_Uke2/*.json'):
    with open(file_path) as f:
        schedules_data = json.load(f)
    for worker_id, calls in schedules_data.items():
        for call_id in calls:
            future_schedules.append({'worker_id': worker_id, 'call_id': call_id})
future_schedules_df = pd.DataFrame(future_schedules)

# %%
future_schedules_df
# Out:
#                                      worker_id  \
# 0       w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960
# 1       w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960
# 2       w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960
# 3       w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960
# 4       w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960
# ...                                        ...
# 260288  w_f5400776-c6cc-4563-b835-b5ee56242aa1
# 260289  w_f5400776-c6cc-4563-b835-b5ee56242aa1
# 260290  w_f5400776-c6cc-4563-b835-b5ee56242aa1
# 260291  w_f5400776-c6cc-4563-b835-b5ee56242aa1
# 260292  w_f5400776-c6cc-4563-b835-b5ee56242aa1
#
#                                        call_id
# 0       c_0195b1db-9c43-4a1b-a0ab-241d46b65ccc
# 1       c_1cc0ef8a-4014-46ea-a8a5-9fb2d2b996bf
# 2       c_cf015bea-77f5-478c-81c4-168e98ac0a35
# 3       c_f7786fe6-39e3-47c5-8539-f7e716189ef4
# 4       c_edc1511a-d8af-4984-be9c-28bed6dfae93
# ...                                        ...
# 260288  c_a703151a-8894-4fe4-b208-514d92c5052c
# 260289  c_0e7226d4-d988-4ee6-a55a-5cf2e6818de3
# 260290  c_a3492ea4-3a2c-4d4a-a915-4503d4312672
# 260291  c_170c7c3a-4228-4192-93a7-c942c8b54828
# 260292  c_e88ca4b8-00bf-480d-85e0-334c24dd11da
#
# [260293 rows x 2 columns]

# %%
# Calculate key performance metrics
def calculate_metrics(report_df):
    return {
        "Average Profit": report_df['call_profit'].mean(),
        "Average Call Time": report_df['call_time'].mean(),
        "Average Recommendation": report_df['likely_to_recommend'].mean(),
        
    }

# %%
future_calls_df
# Out:
#                              date tlf_number  \
# 0       1970-01-01 00:00:00+00:00   20962728
# 1       1970-01-01 00:00:00+00:00   93884912
# 2       1970-01-01 00:00:00+00:00   34997608
# 3       1970-01-01 00:00:00+00:00   08890010
# 4       1970-01-01 00:00:00+00:00   41021032
# ...                           ...        ...
# 260288  1970-01-01 00:00:00+00:00   21482224
# 260289  1970-01-01 00:00:00+00:00   54350588
# 260290  1970-01-01 00:00:00+00:00   78885138
# 260291  1970-01-01 00:00:00+00:00   48763576
# 260292  1970-01-01 00:00:00+00:00   57423650
#
#                               technical_problem difficulty  commission  \
# 0                   device_and_peripheral_setup     medium       705.0
# 1                   device_and_peripheral_setup       hard       846.0
# 2                          email_related_issues     medium       700.0
# 3       software_installation_and_configuration       easy       600.0
# 4                             internet_problems       hard       816.0
# ...                                         ...        ...         ...
# 260288                     email_related_issues       easy       560.0
# 260289            browser_and_web_based_support       easy       520.0
# 260290  software_installation_and_configuration       easy       600.0
# 260291                           teams_problems       hard       798.0
# 260292                            zoom_problems       easy       556.0
#
#                                        call_id   location  price
# 0       c_0195b1db-9c43-4a1b-a0ab-241d46b65ccc  bangalore    705
# 1       c_82aa1a0f-5bf6-49a8-9a32-ceda4b0bea08  bangalore    705
# 2       c_f26adcb6-1fbd-4c5d-a844-e861dd6088e7  bangalore    700
# 3       c_a930dc43-76d4-43fe-a6c4-af82427c65b5  bangalore    750
# 4       c_ee2e7e49-799b-48c0-a0fd-f89a02d7c463  bangalore    680
# ...                                        ...        ...    ...
# 260288  c_592e71fd-a512-4a6d-ac83-46779c378d42  hyderabad    700
# 260289  c_fe0eb66a-f7de-4db0-b421-f98b6a1e387c  hyderabad    650
# 260290  c_4e7ca62b-18d8-45fa-918c-b3da7fa5436b  hyderabad    750
# 260291  c_fc9f040e-99f1-4785-8fbd-e261632d5ae2  hyderabad    665
# 260292  c_93ad8b97-7a5e-450f-adae-c8c42797381e  hyderabad    695
#
# [260293 rows x 8 columns]

# %%
# Calculate metrics for previous and new reports
previous_metrics = calculate_metrics(previous_reports_df)
new_metrics = calculate_metrics(new_reports_df)

# %%
previous_reports_df = previous_reports_df.merge(load_and_flatten_data('extracted/previous_calls', 'call_id'), on='call_id', how='left')
new_reports_df = new_reports_df.merge(load_and_flatten_data('Week2\calls', 'call_id'), on='call_id', how='left')

# %%
previous_reports_df
# Out:
#                                       call_id  \
# 0      c_a317abc5-a7e1-40c3-b486-c4eefdf8be05
# 1      c_256844cb-b710-4da7-8f95-238a7fdd5261
# 2      c_46bfdc38-5130-4e08-9918-4851d84930ce
# 3      c_497ac5ca-8ff3-4773-968c-2e300486c35d
# 4      c_97384374-b420-4259-aaa9-f2e1571928cb
# ...                                       ...
# 72511  c_282338ea-b4a3-4d55-801c-1935c08be259
# 72512  c_9f076c7e-aa1f-44e2-a904-ec7daaec52c4
# 72513  c_bece22d1-0ba0-4208-91f8-366c8267177c
# 72514  c_ac55b479-d0ad-4c68-a637-87b3c360ceb9
# 72515  c_5a9ca763-3a01-491b-9288-e4e17fce0abb
#
#                                     worker_id  call_time  likely_to_recommend  \
# 0      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  57.057332                  1.0
# 1      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  69.294334                  1.0
# 2      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  70.794334                  1.0
# 3      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  54.379299                  1.0
# 4      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  77.457332                  1.0
# ...                                       ...        ...                  ...
# 72511  w_ff6501e8-b49a-4512-a9eb-e06565d21355  37.453295                  1.0
# 72512  w_ff6501e8-b49a-4512-a9eb-e06565d21355  62.093346                  1.0
# 72513  w_ff6501e8-b49a-4512-a9eb-e06565d21355  61.482360                  1.0
# 72514  w_ff6501e8-b49a-4512-a9eb-e06565d21355  32.353295                  1.0
# 72515  w_ff6501e8-b49a-4512-a9eb-e06565d21355  57.151490                  1.0
#
#        professional_score  call_profit                        date tlf_number  \
# 0                     NaN          695  2024-10-19 07:28:55.254686   85062036
# 1                     NaN          735  2024-10-25 08:14:21.255716   56920356
# 2                     NaN          735  2024-10-25 08:05:02.256263   71277349
# 3                     NaN          532  2024-10-25 16:49:01.261099   26307674
# 4                     NaN          834  2024-10-25 13:12:40.265332   44681209
# ...                   ...          ...                         ...        ...
# 72511                 NaN          705  2024-10-24 18:24:02.185299   68091458
# 72512                 NaN          780  2024-10-24 03:11:06.185759   46370406
# 72513                 NaN          864  2024-10-22 12:55:45.188029   38466912
# 72514                 NaN          564  2024-10-20 07:32:03.190272   91733895
# 72515                 NaN          690  2024-10-18 15:38:50.196272   23976720
#
#                     technical_problem difficulty  commission   location
# 0                       zoom_problems     medium       695.0  bangalore
# 1            operating_system_support     medium       735.0  bangalore
# 2            operating_system_support     medium       735.0  bangalore
# 3                      teams_problems       easy       532.0  bangalore
# 4                       zoom_problems       hard       834.0  bangalore
# ...                               ...        ...         ...        ...
# 72511     device_and_peripheral_setup     medium       705.0  hyderabad
# 72512   browser_and_web_based_support       hard       780.0  hyderabad
# 72513  basic_hardware_troubleshooting       hard       864.0  hyderabad
# 72514     device_and_peripheral_setup       easy       564.0  hyderabad
# 72515     cloud_and_storage_solutions     medium       690.0  hyderabad
#
# [72516 rows x 12 columns]

# %%
# Calculate percentage changes
comparison = {
    "Metric": ["Average Profit", "Average Call Time", "Average Recommendation"],
    "Previous": [previous_metrics["Average Profit"], previous_metrics["Average Call Time"], previous_metrics["Average Recommendation"]],
    "New": [new_metrics["Average Profit"], new_metrics["Average Call Time"], new_metrics["Average Recommendation"]],
    "Change (%)": [
        (new_metrics["Average Profit"] - previous_metrics["Average Profit"]) / previous_metrics["Average Profit"] * 100 if previous_metrics["Average Profit"] else None,
        (new_metrics["Average Call Time"] - previous_metrics["Average Call Time"]) / previous_metrics["Average Call Time"] * 100 if previous_metrics["Average Call Time"] else None,
        (new_metrics["Average Recommendation"] - previous_metrics["Average Recommendation"]) / previous_metrics["Average Recommendation"] * 100 if previous_metrics["Average Recommendation"] else None
    ]
}

# Create a DataFrame for comparison
comparison_df = pd.DataFrame(comparison)

# %%
comparison_df
# Out:
#                    Metric    Previous         New  Change (%)
# 0          Average Profit  698.655442  698.894464    0.034212
# 1       Average Call Time   44.539292   43.545245   -2.231845
# 2  Average Recommendation    1.546179    1.544043   -0.138112
