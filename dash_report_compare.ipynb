# %%
import pandas as pd
import json
import glob

# %%
# Load workers data and format correctly
workers_df = pd.read_json('extracted/workers.json').transpose().reset_index()
workers_df.columns = ['worker_id', 'name', 'base_salary']

# %%
# Load prices.json as a dictionary and convert to DataFrame
with open('Week1/prices.json') as f:
    prices_data = json.load(f)
prices_df = pd.DataFrame(list(prices_data.items()), columns=['technical_problem', 'price'])

# %%
# Function to load and flatten data from multiple JSON files in a directory
def load_and_flatten_data(directory, key_field):
    records = []
    for file_path in glob.glob(f'{directory}/*.json'):
        with open(file_path) as f:
            data = json.load(f)
        for location, calls in data.items():
            for call_id, call_info in calls.items():
                call_info['call_id'] = call_id
                call_info['location'] = location
                records.append(call_info)
    return pd.DataFrame(records)

# %%
calls_data = {}
for file_path in glob.glob('extracted/previous_calls/*.json'):
    with open(file_path, 'r') as file:
        file_data = json.load(file
                              )
        for location, calls in file_data.items():
            if location in calls_data:
                calls_data[location].update(calls)  # Merge calls for this location
            else:
                calls_data[location] = calls  # Initialize calls for this location

calls_data
# Out:
# {'bangalore': {'c_a317abc5-a7e1-40c3-b486-c4eefdf8be05': {'date': '2024-10-19 07:28:55.254686',
#    'tlf_number': '85062036',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_78d3cde6-0da9-49f1-91b8-907b180b30a2': {'date': '2024-10-22 22:08:18.254841',
#    'tlf_number': '73320532',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_130313ec-a141-4306-825b-826c63096cff': {'date': '2024-10-26 08:29:09.254885',
#    'tlf_number': '97493770',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_4027388e-7996-4fc2-aef6-c99d66e22b09': {'date': '2024-10-25 07:23:24.254929',
#    'tlf_number': '64380401',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_2d36d2d7-d07f-4431-a699-e0ac84a0b7ce': {'date': '2024-10-22 19:47:52.254979',
#    'tlf_number': '43520611',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_8e470aac-abbb-4af8-88bf-2430173770f6': {'date': '2024-10-19 17:14:53.255018',
#    'tlf_number': '43062341',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_83f1a52d-ed1e-4507-9d1a-651290623740': {'date': '2024-10-22 07:41:21.255057',
#    'tlf_number': '77209736',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_ec7d94e2-246a-4087-943f-2b1316c43c69': {'date': '2024-10-23 00:29:49.255095',
#    'tlf_number': '94081108',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'hard',
#    'commission': 900.0},
#   'c_93058904-6d1b-4ce4-9df7-0bcf09499d26': {'date': '2024-10-23 20:35:58.255133',
#    'tlf_number': '02024590',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'easy',
#    'commission': 564.0},
#   'c_be58f1a4-8140-4ffd-af0f-4be4b1b33f77': {'date': '2024-10-18 14:29:32.255171',
#    'tlf_number': '12716330',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_54a83e58-b754-4147-aa8b-33dc7679a854': {'date': '2024-10-21 10:57:40.255210',
#    'tlf_number': '09033312',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_e7ab163d-9f8c-4fd0-bc15-bd2db8e40086': {'date': '2024-10-23 21:19:52.255248',
#    'tlf_number': '66034493',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_9aa77929-1c12-49d5-88cf-7804cf4706b3': {'date': '2024-10-21 10:17:59.255287',
#    'tlf_number': '63784410',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'easy',
#    'commission': 564.0},
#   'c_784c1426-c316-4fe4-83ea-523fd9baee3e': {'date': '2024-10-26 01:44:32.255324',
#    'tlf_number': '88060074',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'medium',
#    'commission': 665},
#   'c_9ba2b437-34e5-4904-9417-5a297002eb3d': {'date': '2024-10-21 01:27:05.255365',
#    'tlf_number': '61948271',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_8c69cacd-0662-4a1e-b08e-5355da0330d4': {'date': '2024-10-21 17:20:43.255471',
#    'tlf_number': '11487495',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_1bf3bb2e-7e5d-49b1-a88f-727d90aa6a92': {'date': '2024-10-19 09:49:49.255542',
#    'tlf_number': '58521684',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_df3a6486-817b-420b-a93e-55c1ab66ccaf': {'date': '2024-10-18 21:17:44.255647',
#    'tlf_number': '19172356',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_256844cb-b710-4da7-8f95-238a7fdd5261': {'date': '2024-10-25 08:14:21.255716',
#    'tlf_number': '56920356',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_ae4b6b66-98f2-4469-8dc3-4cfccd872a82': {'date': '2024-10-22 05:30:31.255770',
#    'tlf_number': '15561657',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_7833a7df-07cd-4b04-a6e5-a2acd40cdac8': {'date': '2024-10-24 08:25:43.255822',
#    'tlf_number': '90378323',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_c29f81f1-74fc-411f-b7f5-2d94f22cfdd3': {'date': '2024-10-22 07:10:33.255874',
#    'tlf_number': '75607378',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'easy',
#    'commission': 576.0},
#   'c_ee479a33-6d30-4f39-b781-8eb2bd7611d7': {'date': '2024-10-24 23:21:48.255927',
#    'tlf_number': '21797800',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_bfba1cc7-b786-4241-ba0c-f692e42c78c5': {'date': '2024-10-23 21:00:28.255986',
#    'tlf_number': '90608673',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_a1b109fd-56a7-4228-9b5c-892b7b7a04a4': {'date': '2024-10-21 10:53:49.256039',
#    'tlf_number': '24069381',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_dfd8f4f1-491a-4a31-a26a-db101a5b857e': {'date': '2024-10-23 00:24:53.256094',
#    'tlf_number': '98135015',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'hard',
#    'commission': 900.0},
#   'c_80a9c174-6c68-4fb6-b5c1-cb6b4283bcba': {'date': '2024-10-24 10:47:17.256148',
#    'tlf_number': '87035454',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'easy',
#    'commission': 588.0},
#   'c_43f1bb62-602b-435a-b3e8-972405df8217': {'date': '2024-10-20 17:07:16.256203',
#    'tlf_number': '50331262',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_46bfdc38-5130-4e08-9918-4851d84930ce': {'date': '2024-10-25 08:05:02.256263',
#    'tlf_number': '71277349',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_74fc056f-0865-4f69-aa14-3b8b71a01f9a': {'date': '2024-10-25 21:48:19.256319',
#    'tlf_number': '88921434',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_ea8765a0-167d-4647-98a5-4c71cbd567ab': {'date': '2024-10-24 10:55:14.256376',
#    'tlf_number': '65599338',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'hard',
#    'commission': 882.0},
#   'c_ff7d082e-a475-403d-a1c7-ab9a271aca67': {'date': '2024-10-19 06:50:06.256437',
#    'tlf_number': '11013077',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_f0400320-ce4f-4229-b89f-37600f220b38': {'date': '2024-10-22 04:23:49.256496',
#    'tlf_number': '27137415',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_d9ae772d-69e5-4a2e-8969-0fd11edd8ef6': {'date': '2024-10-22 06:42:24.256554',
#    'tlf_number': '19668704',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'medium',
#    'commission': 665},
#   'c_d0a3a497-d298-4a69-a178-36a97671fcb8': {'date': '2024-10-25 11:54:27.256616',
#    'tlf_number': '31127024',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_be5b3c6c-5315-4bbb-9953-c9097f04f167': {'date': '2024-10-20 09:21:17.256675',
#    'tlf_number': '75140792',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_42937e91-7aa8-4657-baec-a10b1da51376': {'date': '2024-10-20 16:27:28.256737',
#    'tlf_number': '51380094',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_d5695b92-625b-4fbb-9ea0-b77749a1f6f8': {'date': '2024-10-23 22:59:43.256799',
#    'tlf_number': '27325572',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_8d3706bf-6def-4e28-8051-e9432b3f7c9e': {'date': '2024-10-19 10:51:10.256856',
#    'tlf_number': '38789046',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'hard',
#    'commission': 828.0},
#   'c_6028e5b0-e966-4107-af14-3b656eac06ea': {'date': '2024-10-20 21:59:36.256912',
#    'tlf_number': '44319124',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_2d481b26-f55f-4023-8584-c8653bccfc90': {'date': '2024-10-22 08:49:20.256954',
#    'tlf_number': '36168609',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_94b2288e-6d80-4bcb-8008-7772a64aca4f': {'date': '2024-10-26 00:27:46.256993',
#    'tlf_number': '64876259',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'hard',
#    'commission': 864.0},
#   'c_0baac679-3ec9-4aed-9d29-255d7e66a49b': {'date': '2024-10-24 12:08:19.257033',
#    'tlf_number': '97996102',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_4199abad-bc23-409e-b5f0-35986cb3ac5d': {'date': '2024-10-21 13:28:35.257076',
#    'tlf_number': '61526480',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'medium',
#    'commission': 665},
#   'c_c1b78b49-34cd-4bd3-a13e-add1ed2bbb76': {'date': '2024-10-22 07:00:08.257114',
#    'tlf_number': '75274579',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_6b21320c-15e1-46e1-96c7-ddefa5de4bca': {'date': '2024-10-21 23:10:27.257153',
#    'tlf_number': '11429609',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_05b54c23-3668-4a21-8eef-8b3eefc67c6c': {'date': '2024-10-24 00:22:24.257192',
#    'tlf_number': '06505854',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'easy',
#    'commission': 560.0},
#   'c_8d1c15b2-2160-4f58-8b07-ed1290555f6e': {'date': '2024-10-25 15:17:51.257230',
#    'tlf_number': '43438715',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_80baa8f2-7dca-47f3-8a7a-9bf29867aa18': {'date': '2024-10-26 09:10:31.257269',
#    'tlf_number': '66160060',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_52437cdf-464b-4417-b96f-4bdf057fee1e': {'date': '2024-10-26 02:27:48.257307',
#    'tlf_number': '46683448',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_bf174cf2-2700-41a9-bae8-32b9daa52234': {'date': '2024-10-22 19:14:56.257344',
#    'tlf_number': '36258112',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_684c7fa9-5e58-41b7-bf73-b649ec4fbc30': {'date': '2024-10-20 00:36:38.257381',
#    'tlf_number': '86565897',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_68fd7172-24ba-4110-b9fb-58547e9637d4': {'date': '2024-10-24 22:38:44.257422',
#    'tlf_number': '74116243',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'medium',
#    'commission': 665},
#   'c_e0b337cd-e39e-4153-9c21-ab70e4d6af9d': {'date': '2024-10-23 19:33:42.257460',
#    'tlf_number': '80872318',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'medium',
#    'commission': 705},
#   'c_b1c49a6d-b9eb-48a3-aee4-3efdd58143ca': {'date': '2024-10-20 00:25:55.257498',
#    'tlf_number': '11963204',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_65bb2f53-3d2c-4f16-ab64-5b79c5fc0b29': {'date': '2024-10-19 00:26:29.257536',
#    'tlf_number': '55324337',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_124eb7d6-5fc5-4aa5-9180-ce14817b783d': {'date': '2024-10-22 21:20:41.257576',
#    'tlf_number': '45773291',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_9af505d9-a74d-43f8-b04f-eabed69007da': {'date': '2024-10-24 07:12:42.257613',
#    'tlf_number': '33036330',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_76f45563-13db-47c7-8bee-6bec28d2d674': {'date': '2024-10-25 22:37:37.257651',
#    'tlf_number': '14480418',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_77a8f32e-f253-464a-af4b-56f8d0f0aebe': {'date': '2024-10-26 08:03:01.257690',
#    'tlf_number': '25203988',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_9f15c651-56ac-464b-9f4e-f22f0a1354f9': {'date': '2024-10-20 22:52:12.257728',
#    'tlf_number': '50599515',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_7afa9604-ea1b-4106-a375-85dd4bd50844': {'date': '2024-10-22 01:48:35.257768',
#    'tlf_number': '56530325',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'hard',
#    'commission': 900.0},
#   'c_292a61ad-3f89-4323-a833-f055bea60de7': {'date': '2024-10-20 08:18:53.257806',
#    'tlf_number': '52221019',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'hard',
#    'commission': 864.0},
#   'c_0f1de2aa-9927-417e-b8b9-9a88baf9ab9b': {'date': '2024-10-25 04:40:20.257844',
#    'tlf_number': '87202533',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_bfd99788-b479-4a9d-8b67-ea7f8f07edad': {'date': '2024-10-22 20:20:24.257883',
#    'tlf_number': '18061215',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_6236aa85-f3b7-40da-8447-cbd668aa53f4': {'date': '2024-10-25 11:35:28.257925',
#    'tlf_number': '27496015',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'hard',
#    'commission': 828.0},
#   'c_a262f9b2-9ea3-44c3-98b1-83f15af8531b': {'date': '2024-10-18 10:39:41.257965',
#    'tlf_number': '67499548',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_feaec321-2712-4325-bd66-04baf663afa3': {'date': '2024-10-25 05:04:22.258003',
#    'tlf_number': '79137766',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_bf9cb878-5cd0-414a-83cd-ce9b2d7f5ad6': {'date': '2024-10-23 16:29:43.258043',
#    'tlf_number': '73562680',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_2604742f-2c74-4529-939e-676de1741b51': {'date': '2024-10-21 10:39:21.258081',
#    'tlf_number': '02507887',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'easy',
#    'commission': 564.0},
#   'c_cfe842d2-6be1-4086-b88a-6c9db60acacc': {'date': '2024-10-19 11:20:02.258119',
#    'tlf_number': '82092132',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'easy',
#    'commission': 588.0},
#   'c_13f3ab86-95d8-4c22-950a-ed3d7031aecb': {'date': '2024-10-18 16:49:37.258157',
#    'tlf_number': '33352972',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_5d3cb6ab-13de-460e-982e-65ff32130e45': {'date': '2024-10-25 08:36:36.258197',
#    'tlf_number': '88342822',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_619215da-e983-42d0-95b2-03d9d1a22e5f': {'date': '2024-10-22 04:03:23.258234',
#    'tlf_number': '31464634',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_562150ad-890c-458a-a607-a6813546f2b4': {'date': '2024-10-20 22:08:05.258273',
#    'tlf_number': '89745573',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_46e6218b-2115-4c2d-914c-fe93a15dc77f': {'date': '2024-10-24 21:44:01.258312',
#    'tlf_number': '70767142',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_b18f938f-49f1-4d03-80d6-2b4b0d8620c0': {'date': '2024-10-24 15:38:10.258350',
#    'tlf_number': '46346993',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_a202735c-8f0a-4b63-baf5-14c393961556': {'date': '2024-10-22 19:19:16.258389',
#    'tlf_number': '27033623',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_306db7f2-8ed4-4245-9a29-24b3b9bb27ec': {'date': '2024-10-24 03:13:16.258429',
#    'tlf_number': '76107457',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_275c1e89-9456-409a-a5ba-5f76e5f83d83': {'date': '2024-10-23 07:58:24.258467',
#    'tlf_number': '03196369',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_7eb8dfc2-ae37-4af2-a4ad-3807a164af75': {'date': '2024-10-23 07:42:51.258505',
#    'tlf_number': '58250164',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_25f7f6b0-9955-4925-a312-40eca66db65d': {'date': '2024-10-21 01:49:39.258542',
#    'tlf_number': '62681565',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_acb72e3b-ed4a-4892-9629-260d18933f51': {'date': '2024-10-25 23:48:49.258580',
#    'tlf_number': '71612483',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_730ae203-26fb-4bbd-af2f-b0fcfbd40a7a': {'date': '2024-10-25 15:14:49.258618',
#    'tlf_number': '39571572',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'easy',
#    'commission': 560.0},
#   'c_956f94e0-6899-4dae-be5a-d670a5c0c6a7': {'date': '2024-10-22 17:28:29.258655',
#    'tlf_number': '12639696',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_ec35766e-9004-4940-97cf-7cb2f05d5da2': {'date': '2024-10-20 21:00:41.258692',
#    'tlf_number': '35722378',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_b293cacf-9db1-47ab-93b1-d4e13ea4bbca': {'date': '2024-10-24 10:13:31.258732',
#    'tlf_number': '13597183',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_8881a9c5-5b6c-4810-ad2d-6da4e5d0acec': {'date': '2024-10-24 06:06:20.258771',
#    'tlf_number': '12726458',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_fbf8bd4e-67f3-4755-a6a1-3d0844b8ce2b': {'date': '2024-10-21 11:11:51.258809',
#    'tlf_number': '25519881',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_bdcc1677-0f30-44a3-b1ef-7d7a21aa7012': {'date': '2024-10-21 14:46:11.258846',
#    'tlf_number': '91732314',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_b70da544-c40e-4883-9fb0-4e76ea2b4a90': {'date': '2024-10-19 19:50:04.258884',
#    'tlf_number': '16393813',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_390d4dec-2928-4f83-b2f1-35f878bebf9f': {'date': '2024-10-25 08:40:32.258922',
#    'tlf_number': '44916526',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_699b4fef-edb5-4db9-8cc5-d0b536e96a8c': {'date': '2024-10-19 08:07:59.258961',
#    'tlf_number': '68173070',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_68a803e9-079e-42ee-95c9-8a828faedde6': {'date': '2024-10-20 19:57:23.259002',
#    'tlf_number': '06644331',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_87c34864-f716-408f-a1ca-326122a4585e': {'date': '2024-10-22 17:03:22.259039',
#    'tlf_number': '63311279',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'easy',
#    'commission': 560.0},
#   'c_eeda17d6-4d8d-42de-be16-aaa695f0edf7': {'date': '2024-10-23 19:12:21.259078',
#    'tlf_number': '72859728',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_73982d58-e384-4047-a3a2-dbea0a018ade': {'date': '2024-10-18 12:56:43.259116',
#    'tlf_number': '63614428',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_3cbf3a10-514d-46d8-bcff-1408a2409bb4': {'date': '2024-10-24 17:02:39.259154',
#    'tlf_number': '79559857',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_095e40c4-1648-4884-aec6-488d4c1a2733': {'date': '2024-10-23 10:47:18.259193',
#    'tlf_number': '67977276',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_a1e76fb3-bcf3-47d7-9f52-6fbe8fc5afa9': {'date': '2024-10-20 23:50:22.259232',
#    'tlf_number': '17682300',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_fa258c20-5121-4657-a745-a2ecc84ee98f': {'date': '2024-10-20 04:20:02.259270',
#    'tlf_number': '94994638',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_2518f318-76ed-4e79-ab25-055c8b1b97eb': {'date': '2024-10-21 16:45:01.259308',
#    'tlf_number': '84561444',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_02904b74-eaca-432e-ab7a-1b8bcaf83b7f': {'date': '2024-10-23 04:39:23.259350',
#    'tlf_number': '28429685',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'hard',
#    'commission': 828.0},
#   'c_1ceeabe1-d52b-4da4-8f28-85e036c0b6dc': {'date': '2024-10-18 12:04:17.259390',
#    'tlf_number': '36483450',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'easy',
#    'commission': 576.0},
#   'c_cff61db4-d323-48ac-9dfe-5b05ce0db0af': {'date': '2024-10-18 21:04:44.259429',
#    'tlf_number': '29542862',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'hard',
#    'commission': 864.0},
#   'c_2ae1b19d-c4bf-4a40-8591-cbe4f3a65763': {'date': '2024-10-24 00:52:55.259468',
#    'tlf_number': '12960671',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_574da88d-05de-4f1c-9fe5-a8f52e59d9ca': {'date': '2024-10-23 08:09:39.259596',
#    'tlf_number': '00596770',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'hard',
#    'commission': 864.0},
#   'c_ce34eb3b-a814-4180-b988-954c8048840e': {'date': '2024-10-20 07:00:06.259638',
#    'tlf_number': '29733194',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_4747d863-9023-404f-98f7-12973a998807': {'date': '2024-10-20 03:38:15.259679',
#    'tlf_number': '61137815',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_707ffd12-8e46-4c89-9553-65a029e0bdc2': {'date': '2024-10-22 11:18:53.259717',
#    'tlf_number': '25994836',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'hard',
#    'commission': 882.0},
#   'c_377fd05e-ba92-4623-98fb-e64d8c1cc501': {'date': '2024-10-20 17:11:20.259755',
#    'tlf_number': '92531276',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'medium',
#    'commission': 665},
#   'c_07f8af94-f664-485f-9833-334c5e576e40': {'date': '2024-10-22 11:12:40.259794',
#    'tlf_number': '08234984',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'hard',
#    'commission': 864.0},
#   'c_3f11f5b0-5c65-4afb-8d60-a127912a2908': {'date': '2024-10-23 19:18:01.259832',
#    'tlf_number': '32939460',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'medium',
#    'commission': 705},
#   'c_a5a7cbea-64b9-4ead-a7b5-62ec9c3ec33b': {'date': '2024-10-20 07:51:28.259870',
#    'tlf_number': '39909824',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'easy',
#    'commission': 588.0},
#   'c_65712e98-b4ab-4519-82ac-002da81f9e02': {'date': '2024-10-21 08:56:32.259908',
#    'tlf_number': '65223724',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_cc5a67d3-069f-436b-9b46-f791d18d7ab3': {'date': '2024-10-25 09:35:37.259947',
#    'tlf_number': '95475017',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_095ab996-89b7-452c-b29f-c35e9328ff68': {'date': '2024-10-22 22:35:46.259987',
#    'tlf_number': '53031641',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_fc949e27-4a38-41f1-9e7b-2047e10c14b4': {'date': '2024-10-21 03:07:32.260025',
#    'tlf_number': '47655471',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'easy',
#    'commission': 576.0},
#   'c_3b7df17e-a6cc-4084-9d00-82cd364bf362': {'date': '2024-10-25 21:12:40.260063',
#    'tlf_number': '13261192',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_8a00f2f9-40bf-4d2d-9eda-efadbfa7b343': {'date': '2024-10-21 16:15:29.260100',
#    'tlf_number': '98798626',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'medium',
#    'commission': 705},
#   'c_6fc906b8-a0b7-4303-b3ea-1cec8a068538': {'date': '2024-10-25 15:39:56.260137',
#    'tlf_number': '15047980',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_9f214d1d-4a46-477e-a61f-8a2fd8811237': {'date': '2024-10-20 21:11:18.260174',
#    'tlf_number': '09848757',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'easy',
#    'commission': 560.0},
#   'c_130c2c74-4b53-472b-887a-62fc1a0b5747': {'date': '2024-10-19 00:52:34.260246',
#    'tlf_number': '19289743',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_06f25c96-8a23-4556-b222-ac7e5de1685d': {'date': '2024-10-20 03:24:30.260293',
#    'tlf_number': '16456003',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_cd84a80d-b12d-488b-8f1d-74172a69f725': {'date': '2024-10-26 09:20:41.260333',
#    'tlf_number': '32771946',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_83bdad32-377c-460b-a972-c3b5bd5bba16': {'date': '2024-10-22 03:06:58.260373',
#    'tlf_number': '73430731',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'medium',
#    'commission': 710},
#   'c_0eac7998-4a16-4d3e-b6c6-e0c3b4549c6f': {'date': '2024-10-22 01:12:34.260415',
#    'tlf_number': '40560469',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_5185a7ce-c740-40f5-851f-ac4f5ade9962': {'date': '2024-10-19 23:10:41.260453',
#    'tlf_number': '37418268',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_1c6f4ba3-b72b-412f-8ef5-34e9d7d42996': {'date': '2024-10-19 14:58:33.260491',
#    'tlf_number': '35912196',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_8750ef03-48dd-4d7d-9c49-8962d6f805b0': {'date': '2024-10-25 12:54:45.260529',
#    'tlf_number': '75090672',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_eb1cbde2-229f-4fae-a876-5439db968970': {'date': '2024-10-26 01:43:44.260566',
#    'tlf_number': '56744527',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_dffb3f8e-bed5-4b62-af26-deaf66781567': {'date': '2024-10-25 23:42:09.260603',
#    'tlf_number': '30104452',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_296c6efd-bae5-40ac-b8cb-c4c3b3c4a0e3': {'date': '2024-10-25 21:46:21.260641',
#    'tlf_number': '48278264',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_427c0dc8-33c5-4c00-a996-6363c749ffdb': {'date': '2024-10-19 01:04:27.260679',
#    'tlf_number': '72212737',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'medium',
#    'commission': 705},
#   'c_d4cdf2d4-2fb9-4f61-a17f-87e67d1106b6': {'date': '2024-10-21 08:45:21.260717',
#    'tlf_number': '88388124',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'medium',
#    'commission': 710},
#   'c_a8ffa8d0-074f-42ef-8b92-3780e9a03314': {'date': '2024-10-20 10:13:18.260754',
#    'tlf_number': '20467515',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'medium',
#    'commission': 710},
#   'c_7b952097-91ce-4cf1-9f50-68e2fdf0d7be': {'date': '2024-10-24 05:41:20.260791',
#    'tlf_number': '08691655',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_b9d91e54-ab3e-43c3-94b1-a82b6261dfee': {'date': '2024-10-18 11:27:27.260829',
#    'tlf_number': '58606329',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'medium',
#    'commission': 665},
#   'c_00aa7787-8c25-4d64-aa06-825612df255f': {'date': '2024-10-23 21:48:25.260866',
#    'tlf_number': '25716627',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_3ab192ab-3bfb-487c-9199-3a135cf281db': {'date': '2024-10-20 10:08:58.260904',
#    'tlf_number': '88286652',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_50ded846-d272-4461-8527-b6e43b82bed4': {'date': '2024-10-22 14:09:32.260942',
#    'tlf_number': '80690992',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'easy',
#    'commission': 560.0},
#   'c_48878070-0b75-4d32-a145-f83cd0e7f2b0': {'date': '2024-10-20 17:29:50.260985',
#    'tlf_number': '41785630',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_aa5892ab-c0e7-4d46-b27b-12243a8a8550': {'date': '2024-10-25 21:23:01.261024',
#    'tlf_number': '99358253',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_8beb75bf-6cfc-47ce-a80d-4c54526f9f56': {'date': '2024-10-22 02:32:12.261062',
#    'tlf_number': '45519624',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'medium',
#    'commission': 665},
#   'c_497ac5ca-8ff3-4773-968c-2e300486c35d': {'date': '2024-10-25 16:49:01.261099',
#    'tlf_number': '26307674',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_f9766105-094a-444c-b060-cfb9c9451755': {'date': '2024-10-25 14:20:15.261136',
#    'tlf_number': '41721617',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_a6da0eeb-0466-430a-b3d6-ee2f0863be86': {'date': '2024-10-20 08:26:24.261173',
#    'tlf_number': '21982259',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_be5a64a0-7b7f-480a-8ebd-a921e0a14da7': {'date': '2024-10-19 21:08:26.261211',
#    'tlf_number': '08014092',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_0b764963-7a8e-4ba1-8cbf-aa873e4ae66e': {'date': '2024-10-26 09:43:46.261249',
#    'tlf_number': '53145913',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_728f5ab3-db0d-4c3b-a8dd-d60607c5e62e': {'date': '2024-10-25 07:40:27.261288',
#    'tlf_number': '01347268',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_bb39c128-ebbb-4d61-ba61-468597dbb584': {'date': '2024-10-23 23:24:58.261325',
#    'tlf_number': '63712127',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_d00b85f4-82d6-41fd-b81c-4e4dec4558f1': {'date': '2024-10-24 04:51:24.261366',
#    'tlf_number': '46631234',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'hard',
#    'commission': 828.0},
#   'c_e94ad7ab-797b-41b0-aa13-86fbd97edacf': {'date': '2024-10-20 16:25:59.261406',
#    'tlf_number': '60169941',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'easy',
#    'commission': 532.0},
#   'c_288b8dfa-5e32-490b-ab4c-d7e43391ab9f': {'date': '2024-10-21 14:27:50.261447',
#    'tlf_number': '00633368',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_57cc9c2c-582d-463e-ab78-7b2e4d426136': {'date': '2024-10-23 14:40:26.261488',
#    'tlf_number': '10890176',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'medium',
#    'commission': 710},
#   'c_376b8062-9822-4c14-a804-ff2e497f062a': {'date': '2024-10-24 02:52:36.261526',
#    'tlf_number': '65285474',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_f23aa9c9-6565-4c6d-b8ff-4c014806705f': {'date': '2024-10-22 09:25:34.261566',
#    'tlf_number': '41139583',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_140d8849-6139-49ee-b545-85feff9a9a15': {'date': '2024-10-20 08:46:30.261604',
#    'tlf_number': '37847666',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_cb9ec9fe-0562-460f-a436-0fcf0ed1b5f4': {'date': '2024-10-20 12:50:02.261642',
#    'tlf_number': '16434337',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_32cd3cef-9216-4047-80a3-c5e01c8fd7c4': {'date': '2024-10-23 15:53:47.261680',
#    'tlf_number': '08100592',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_96a97a2a-1964-40d0-ba68-c0c71d6f2ecf': {'date': '2024-10-22 08:48:36.261717',
#    'tlf_number': '61925546',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_ceb42c5e-8e46-452b-a2ba-4a749abd95ba': {'date': '2024-10-21 21:58:36.261755',
#    'tlf_number': '78104540',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'hard',
#    'commission': 882.0},
#   'c_95959cab-bfdc-4bff-b61b-db139b856f33': {'date': '2024-10-18 19:34:00.261793',
#    'tlf_number': '73444620',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_de8e5f0b-bd9e-4725-8467-cd3565b747ae': {'date': '2024-10-19 03:15:31.261831',
#    'tlf_number': '61702741',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_5fcb7ffb-04f0-4b9f-843a-043018dbf44a': {'date': '2024-10-19 05:55:20.261869',
#    'tlf_number': '73241687',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'hard',
#    'commission': 828.0},
#   'c_0809e1ae-17a5-4d75-8e2a-38d4e4201c95': {'date': '2024-10-18 14:06:19.261907',
#    'tlf_number': '13068376',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_42c110fd-c518-4151-a3c0-73c91d87f3f1': {'date': '2024-10-23 12:50:38.261945',
#    'tlf_number': '60419729',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'easy',
#    'commission': 588.0},
#   'c_ca8b06d9-3268-4447-b9af-ec95df083f31': {'date': '2024-10-22 21:55:11.261993',
#    'tlf_number': '80741932',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_3b2e19d6-a032-4331-a268-df2eb8d61880': {'date': '2024-10-19 22:15:20.262031',
#    'tlf_number': '40997046',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'easy',
#    'commission': 576.0},
#   'c_47e75783-88a6-479b-ba27-a03f8cd06f38': {'date': '2024-10-25 04:24:09.262068',
#    'tlf_number': '23031726',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'hard',
#    'commission': 882.0},
#   'c_900a091e-e236-4b5e-bd93-26308ff1227e': {'date': '2024-10-20 04:29:39.262108',
#    'tlf_number': '02480717',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_8fbe968d-7674-43a8-8488-31658ee0f518': {'date': '2024-10-21 15:35:06.262148',
#    'tlf_number': '23993270',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_68771411-9b59-42cf-a8bd-dca5d93bbbad': {'date': '2024-10-18 20:16:30.262187',
#    'tlf_number': '78395559',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'medium',
#    'commission': 665},
#   'c_c5f8b159-48d1-40d4-b41b-a925e5f3b6c0': {'date': '2024-10-20 09:12:45.262225',
#    'tlf_number': '15573845',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'hard',
#    'commission': 834.0},
#   'c_ec7fe2f8-5ed0-4481-8577-de3776a9f261': {'date': '2024-10-24 16:02:06.262262',
#    'tlf_number': '51479074',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'hard',
#    'commission': 864.0},
#   'c_6fae037d-c1eb-4a98-9ff2-81f2dc7221a5': {'date': '2024-10-23 11:58:09.262301',
#    'tlf_number': '15781096',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_966f0fd3-6f20-444e-9362-5b8d0661df3b': {'date': '2024-10-21 00:22:36.262338',
#    'tlf_number': '15288870',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_46e8026b-8643-4070-a894-38bbfd53d0fa': {'date': '2024-10-19 07:57:31.262376',
#    'tlf_number': '89676146',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_fde9100d-006d-4594-933b-847906d78bd6': {'date': '2024-10-19 18:20:26.262414',
#    'tlf_number': '04994850',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_d5274ef0-3462-4e01-b020-f682d57f19e0': {'date': '2024-10-24 16:33:02.262451',
#    'tlf_number': '77144984',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'hard',
#    'commission': 834.0},
#   'c_8a0eeb67-a2b1-4592-a6e7-291e6ff86b62': {'date': '2024-10-25 22:42:12.262490',
#    'tlf_number': '96276382',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_27bcd2ec-21e5-4fc3-8dd6-e35f7f2d1ee1': {'date': '2024-10-22 00:11:26.262532',
#    'tlf_number': '40535785',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_19c70f69-e763-49e5-8f6f-a825bce9f752': {'date': '2024-10-21 01:42:30.262569',
#    'tlf_number': '21553627',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_307649ce-d278-491d-9720-6706830c8a5b': {'date': '2024-10-23 04:17:32.262607',
#    'tlf_number': '01513212',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_b7f20862-2ba6-495f-8f73-87d4508a62ef': {'date': '2024-10-26 09:11:53.262644',
#    'tlf_number': '24267000',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'easy',
#    'commission': 564.0},
#   'c_06e58bc0-3a5e-4299-9aeb-313d7a6fc37b': {'date': '2024-10-19 10:49:35.262682',
#    'tlf_number': '30013066',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_db109b53-4fb2-4af8-aa43-25206a7b9b27': {'date': '2024-10-26 03:54:51.262719',
#    'tlf_number': '53085854',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_1f702e8a-d38b-4135-bcab-407baa9ae00d': {'date': '2024-10-19 08:51:27.262757',
#    'tlf_number': '78213149',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_f4d4a0cd-5c31-4fb9-9be0-749c9f329c84': {'date': '2024-10-25 06:47:42.262795',
#    'tlf_number': '91495101',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_9eb93f4c-ad1c-4230-a82b-8ed28c5c894c': {'date': '2024-10-24 22:39:47.262833',
#    'tlf_number': '16480921',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'medium',
#    'commission': 750},
#   'c_700f5d82-336b-4dfb-b5d0-a471a458b1a6': {'date': '2024-10-24 03:48:59.262870',
#    'tlf_number': '07436552',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'medium',
#    'commission': 665},
#   'c_d8a9093c-6867-49d5-8183-387c0626db87': {'date': '2024-10-19 20:19:24.262908',
#    'tlf_number': '82747160',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_b384e0c5-8d50-434c-9a1e-aa4bdb281641': {'date': '2024-10-25 20:20:59.262946',
#    'tlf_number': '42109953',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_ba24a058-1d66-4808-8003-a0191583f903': {'date': '2024-10-23 23:00:21.262983',
#    'tlf_number': '04606637',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'medium',
#    'commission': 705},
#   'c_59be9587-0c56-43aa-b5ed-5f14b74f18b0': {'date': '2024-10-23 10:26:51.263021',
#    'tlf_number': '39573341',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_fa41064a-b4ad-43a9-9572-3ddfdce5568c': {'date': '2024-10-19 17:26:38.263059',
#    'tlf_number': '23746058',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_a777c866-10fa-4bd7-bd0b-63d174fd16da': {'date': '2024-10-20 15:13:41.263097',
#    'tlf_number': '52634409',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_e2d11472-9c02-4e95-8a99-47c73594507a': {'date': '2024-10-25 16:55:39.263134',
#    'tlf_number': '57683913',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'hard',
#    'commission': 834.0},
#   'c_08f8d28b-f01c-46b0-9381-134dbae61aa2': {'date': '2024-10-21 13:03:53.263172',
#    'tlf_number': '28735089',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_a315fd66-7951-47d4-ac7f-88c2327d0fab': {'date': '2024-10-25 17:36:20.263209',
#    'tlf_number': '85195188',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_8136c83a-2c76-4a07-820e-437f537a73ee': {'date': '2024-10-20 23:44:19.263247',
#    'tlf_number': '52629129',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_0b0e9928-7213-4315-bf71-e5719168ce11': {'date': '2024-10-23 17:05:39.263285',
#    'tlf_number': '04300667',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_b37db04a-5451-4be6-b5cc-00bcbb82a818': {'date': '2024-10-24 12:44:55.263323',
#    'tlf_number': '85219588',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_58dd0b6b-9c98-4e62-89ab-0884d6c84580': {'date': '2024-10-22 12:00:36.263360',
#    'tlf_number': '88439421',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_29dcdb9b-0de4-4569-9618-8316142168d9': {'date': '2024-10-24 19:37:40.263399',
#    'tlf_number': '18920935',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_08cd44f9-883d-4b9d-8b17-7257238a580e': {'date': '2024-10-22 09:00:38.263437',
#    'tlf_number': '15468008',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_fa6f6322-9f17-4ed1-af91-934d48b421a0': {'date': '2024-10-23 07:27:13.263475',
#    'tlf_number': '09036286',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_3217ce2f-534b-4fe2-b416-f28c6130723c': {'date': '2024-10-24 14:07:14.263597',
#    'tlf_number': '93052636',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_98cf6e41-742a-43e1-af1f-2a48efc44f17': {'date': '2024-10-25 05:02:29.263671',
#    'tlf_number': '97610381',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_91ac6a76-4dc5-4373-b558-663396566e4f': {'date': '2024-10-18 11:28:19.263714',
#    'tlf_number': '88013340',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_68586e49-dd04-4420-8a47-251c7f8f8c78': {'date': '2024-10-25 14:19:22.263753',
#    'tlf_number': '28229871',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_ef47c3ee-93bc-4fbf-9afb-3c38579ca419': {'date': '2024-10-26 00:30:32.263801',
#    'tlf_number': '97439654',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'hard',
#    'commission': 864.0},
#   'c_7db6d53f-b5b2-45a9-87f9-a41b69df2b65': {'date': '2024-10-24 07:50:11.263840',
#    'tlf_number': '23252405',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_ab553d3f-c37c-4bcc-9677-636f7e3ffe65': {'date': '2024-10-23 03:51:37.263878',
#    'tlf_number': '15435365',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_a8446d92-ac90-4039-a899-55f967adaf11': {'date': '2024-10-22 09:44:08.263916',
#    'tlf_number': '12585419',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_a1650f09-9d0c-4eac-af08-a135b32a6795': {'date': '2024-10-21 14:48:42.263954',
#    'tlf_number': '05832860',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'medium',
#    'commission': 705},
#   'c_8acbd4d4-4854-45f6-828f-a69064904b5d': {'date': '2024-10-24 06:05:22.263994',
#    'tlf_number': '93557261',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_99f12c18-e6f9-403a-8da2-e3b0384403ef': {'date': '2024-10-23 09:41:36.264031',
#    'tlf_number': '00742949',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_ba9ab8de-e1ff-4367-9ae4-10427b32543f': {'date': '2024-10-20 07:46:30.264070',
#    'tlf_number': '32531403',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_3ba4ffeb-ae5f-42d7-bb72-09fab6936318': {'date': '2024-10-25 20:43:34.264107',
#    'tlf_number': '60696136',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_a43a0f1a-70af-407e-8c50-f5be23a302f9': {'date': '2024-10-18 23:53:10.264151',
#    'tlf_number': '35825399',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'easy',
#    'commission': 576.0},
#   'c_577070dd-7dbf-49fb-968b-74389ce59f59': {'date': '2024-10-23 11:29:47.264188',
#    'tlf_number': '84981492',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'hard',
#    'commission': 834.0},
#   'c_d3183fd3-797a-4fe9-94f8-e187e78f0198': {'date': '2024-10-23 14:04:40.264226',
#    'tlf_number': '46900377',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_b39cc32b-97a5-4222-9b0b-f0a899f8113c': {'date': '2024-10-20 01:39:00.264263',
#    'tlf_number': '65359822',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'hard',
#    'commission': 834.0},
#   'c_ebf61205-5c13-4db1-af6c-dc1d16c42a14': {'date': '2024-10-21 23:11:54.264302',
#    'tlf_number': '34315639',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
# ...
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'hard',
#    'commission': 834.0},
#   'c_f779f5e9-0a19-4278-91e9-a58f4afae149': {'date': '2024-10-21 12:29:26.167066',
#    'tlf_number': '95774664',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_9d55aef1-975b-4d35-aea6-3de5d82f3ae7': {'date': '2024-10-26 08:31:54.167104',
#    'tlf_number': '91947345',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_acb2dc17-c979-4cc9-8e0d-d60c392ae425': {'date': '2024-10-25 03:31:38.167142',
#    'tlf_number': '72809584',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_566e234f-bccc-4382-bf1b-fb03d362ba4f': {'date': '2024-10-23 18:11:34.167180',
#    'tlf_number': '75105055',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'medium',
#    'commission': 705},
#   'c_4c3e05bd-ba4e-436b-9ac9-63a8be6a8cb7': {'date': '2024-10-25 17:22:55.167217',
#    'tlf_number': '15145089',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'easy',
#    'commission': 560.0},
#   'c_7e48f42c-8441-4366-8a74-6fb6274e02e7': {'date': '2024-10-26 08:42:18.167256',
#    'tlf_number': '74629489',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_3e792246-5d63-4102-bcca-cd64873e0097': {'date': '2024-10-25 19:39:33.167294',
#    'tlf_number': '80691208',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_95b46b10-15df-437f-9f3a-1fb9b4ddfe8e': {'date': '2024-10-19 10:44:30.167331',
#    'tlf_number': '35762779',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_804470d2-41d8-477d-918c-60e22a5adf9c': {'date': '2024-10-25 14:31:15.167444',
#    'tlf_number': '91102644',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_be76df62-e590-4d33-8ecf-e93235a15d58': {'date': '2024-10-26 03:16:25.167492',
#    'tlf_number': '30678366',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'medium',
#    'commission': 665},
#   'c_60eb7c38-7bff-4279-bdc8-e6a5f7ffb482': {'date': '2024-10-21 08:28:51.167532',
#    'tlf_number': '59219450',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_6eafe61b-c0da-484b-b5ad-e98030aef6a4': {'date': '2024-10-25 07:21:46.167571',
#    'tlf_number': '01773269',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_3e4ab0d0-d3cf-4011-9d02-c6a79f99d00e': {'date': '2024-10-19 03:36:59.167609',
#    'tlf_number': '73976633',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_0adb40e1-f109-4e3e-bd1a-b9fc12dbc3ea': {'date': '2024-10-21 10:36:44.167647',
#    'tlf_number': '39497654',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'hard',
#    'commission': 834.0},
#   'c_dc3268dd-c48b-436c-9998-370126c2a694': {'date': '2024-10-26 04:47:35.167686',
#    'tlf_number': '07743764',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_314bb496-af92-4ef7-8a19-27925199a0c0': {'date': '2024-10-19 20:32:41.167724',
#    'tlf_number': '21475464',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'hard',
#    'commission': 780.0},
#   'c_7e2b3d2d-ba6c-4272-8b50-2dc997568935': {'date': '2024-10-21 05:03:18.167762',
#    'tlf_number': '93497097',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'easy',
#    'commission': 544.0},
#   'c_a1f692fd-d806-4786-96a9-a30e801f717d': {'date': '2024-10-21 13:31:15.167800',
#    'tlf_number': '86241215',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'easy',
#    'commission': 588.0},
#   'c_754d774b-7274-477e-a450-323790ea31f4': {'date': '2024-10-21 01:51:10.167838',
#    'tlf_number': '37630300',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_603ce923-c249-4767-a0f4-53e3a68b0c01': {'date': '2024-10-25 06:38:02.167875',
#    'tlf_number': '00950062',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   'c_3e1fe6b2-0167-4591-9b79-ec62f43bb686': {'date': '2024-10-20 03:21:03.167912',
#    'tlf_number': '24050185',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_69bcc776-be2f-4bc1-8766-2f7dd5b744e4': {'date': '2024-10-24 08:49:28.167949',
#    'tlf_number': '67400561',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'medium',
#    'commission': 665},
#   'c_51131c14-6d6d-4b30-b107-14d0bbfeb193': {'date': '2024-10-22 18:01:58.167986',
#    'tlf_number': '51037872',
#    'technical_problem': 'teams_problems',
#    'difficulty': 'hard',
#    'commission': 798.0},
#   'c_87bd41b3-2bf0-4135-9e76-dee81cd240b5': {'date': '2024-10-24 17:03:22.168024',
#    'tlf_number': '89402837',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_42d89bd1-eec2-4332-8326-57184bbd3aac': {'date': '2024-10-26 06:02:04.168061',
#    'tlf_number': '17249181',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'easy',
#    'commission': 600.0},
#   'c_4c7551d3-e176-4a1f-bed1-a72af0a4364e': {'date': '2024-10-20 09:50:45.168099',
#    'tlf_number': '41839845',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'hard',
#    'commission': 852.0},
#   'c_d71b413d-fa57-430a-8717-36886977a64b': {'date': '2024-10-19 11:05:55.168136',
#    'tlf_number': '63843209',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'hard',
#    'commission': 828.0},
#   'c_dc7a43bb-44f6-4eec-b110-6cf5154584b0': {'date': '2024-10-19 13:00:44.168174',
#    'tlf_number': '60828732',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'hard',
#    'commission': 882.0},
#   'c_41c432b5-5401-46d4-9ff6-fd35bed56a50': {'date': '2024-10-20 05:26:47.168211',
#    'tlf_number': '32174347',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_92ab9dff-3120-4c2d-9261-5de0ea35123f': {'date': '2024-10-19 10:26:47.168248',
#    'tlf_number': '49064162',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'medium',
#    'commission': 750},
#   'c_504691ab-6f1c-456b-9b22-7e9c0d3c27c5': {'date': '2024-10-24 23:40:58.168285',
#    'tlf_number': '37910541',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_422a4963-17a1-40d3-b0b2-7d922487ac24': {'date': '2024-10-20 16:23:40.168324',
#    'tlf_number': '01405510',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_bdaf36b8-7885-4139-85ae-fb5e1bd096d1': {'date': '2024-10-24 04:28:56.168430',
#    'tlf_number': '52028191',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'medium',
#    'commission': 705},
#   'c_9b05d0a3-cb5f-4e43-a1fd-e4210533d686': {'date': '2024-10-18 22:27:14.168530',
#    'tlf_number': '30388119',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_6e319ba5-3b03-4fcc-adde-1e211b11f4ac': {'date': '2024-10-23 08:25:47.168598',
#    'tlf_number': '86122260',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_5c7c0395-4386-40bb-a637-0a6c554c2209': {'date': '2024-10-20 22:18:31.168640',
#    'tlf_number': '80655195',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'medium',
#    'commission': 750},
#   'c_01131563-8ed8-4334-8ddc-9b5e12c3e6d5': {'date': '2024-10-23 08:04:03.168679',
#    'tlf_number': '92440666',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'medium',
#    'commission': 720},
#   'c_159128b7-c7ef-45c3-9438-9c31fd978bf4': {'date': '2024-10-20 05:57:38.168727',
#    'tlf_number': '68425919',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_eccebe7b-3110-4d55-9432-638883331329': {'date': '2024-10-26 02:43:22.168766',
#    'tlf_number': '51926899',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'easy',
#    'commission': 564.0},
#   'c_afd80cae-3673-4ae7-8627-d4bdbff698e7': {'date': '2024-10-19 01:13:56.168814',
#    'tlf_number': '93149455',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'medium',
#    'commission': 690},
#   'c_b693a148-1fb7-4d01-a706-11995a3d9737': {'date': '2024-10-19 15:53:35.168853',
#    'tlf_number': '98244961',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_082bfc67-c27b-441e-9a40-2322a2147782': {'date': '2024-10-24 09:08:01.168892',
#    'tlf_number': '76934609',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_4485c4a8-f8a3-48f5-91c6-09881963e767': {'date': '2024-10-22 23:22:51.168930',
#    'tlf_number': '62578410',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'medium',
#    'commission': 710},
#   'c_8f722727-c054-458a-b758-2c85de618e69': {'date': '2024-10-24 22:22:19.168969',
#    'tlf_number': '69788493',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'medium',
#    'commission': 710},
#   'c_abcedc81-dfd1-4c8b-b8d8-a01172293c6c': {'date': '2024-10-22 03:31:30.169006',
#    'tlf_number': '99001502',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_a348a969-ea3e-4080-bde0-c7b0e03acf94': {'date': '2024-10-19 02:32:22.169044',
#    'tlf_number': '12077780',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'medium',
#    'commission': 750},
#   'c_b59e6960-51a2-4bf6-8ce7-87485d7b0891': {'date': '2024-10-23 00:15:50.169081',
#    'tlf_number': '37235995',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_309513de-3f74-42d6-bb81-801051b3a63b': {'date': '2024-10-23 01:17:49.169119',
#    'tlf_number': '90384648',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_057e5425-c807-4a3c-b827-04661ec2abf3': {'date': '2024-10-20 04:14:32.169165',
#    'tlf_number': '54129960',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_447bb82d-3c45-4796-85ea-76c67ab02a3d': {'date': '2024-10-26 09:16:57.169203',
#    'tlf_number': '84643800',
#    'technical_problem': 'software_installation_and_configuration',
#    'difficulty': 'medium',
#    'commission': 750},
#   'c_db8a3469-0511-4fe4-a7cd-d217ae1f7504': {'date': '2024-10-26 06:39:01.169241',
#    'tlf_number': '63091515',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_27a54680-d809-4f39-8f16-809eb7572e2f': {'date': '2024-10-23 09:57:01.169280',
#    'tlf_number': '80836427',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'medium',
#    'commission': 700},
#   'c_ba0b949b-0410-449b-ae42-9f6cf8cc971f': {'date': '2024-10-23 20:47:49.169321',
#    'tlf_number': '42155866',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_8e0ff769-a4a9-4fd5-949e-4f95b4ee5826': {'date': '2024-10-25 21:37:12.169395',
#    'tlf_number': '86352736',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'easy',
#    'commission': 560.0},
#   'c_225db5ce-1993-454a-a040-df2ebc9a578e': {'date': '2024-10-22 17:59:19.169481',
#    'tlf_number': '92759656',
#    'technical_problem': 'basic_hardware_troubleshooting',
#    'difficulty': 'easy',
#    'commission': 576.0},
#   'c_7c9eb92c-ee1c-4298-8489-438f1e501857': {'date': '2024-10-25 07:40:15.169556',
#    'tlf_number': '51831384',
#    'technical_problem': 'cloud_and_storage_solutions',
#    'difficulty': 'easy',
#    'commission': 552.0},
#   'c_347ac033-9b87-4493-914e-cc98dac8e766': {'date': '2024-10-22 07:49:58.169596',
#    'tlf_number': '95386395',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_8b1860c4-8956-4b2c-9cd7-3e9526c308ea': {'date': '2024-10-21 15:20:20.169634',
#    'tlf_number': '51128730',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'medium',
#    'commission': 695},
#   'c_d3de6497-51be-4b44-9877-cbf9e77acf2a': {'date': '2024-10-25 14:48:04.169673',
#    'tlf_number': '40535181',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'medium',
#    'commission': 705},
#   'c_88938906-f3b1-466e-880a-461cde6ec148': {'date': '2024-10-20 07:37:00.169711',
#    'tlf_number': '65819771',
#    'technical_problem': 'zoom_problems',
#    'difficulty': 'easy',
#    'commission': 556.0},
#   'c_6edad417-15b9-4c93-a48a-ae066eabbf03': {'date': '2024-10-25 02:17:52.169750',
#    'tlf_number': '29055608',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'medium',
#    'commission': 680},
#   'c_69f90b6a-2f24-4a07-bbf1-8b7f70b1155f': {'date': '2024-10-23 12:39:19.169788',
#    'tlf_number': '84591981',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_85059195-571b-482b-af88-c0fa84128bfc': {'date': '2024-10-22 22:14:01.169826',
#    'tlf_number': '87750320',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'easy',
#    'commission': 568.0},
#   'c_e6612d7f-0860-4c28-9a7d-90ec9a74b2e7': {'date': '2024-10-24 19:39:34.169864',
#    'tlf_number': '38088334',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_05d608b3-e639-4cb5-9546-88ed557298bd': {'date': '2024-10-20 10:05:56.169908',
#    'tlf_number': '48585681',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'medium',
#    'commission': 650},
#   'c_4ddd4484-7d38-4607-b048-43d946704672': {'date': '2024-10-18 17:36:18.169946',
#    'tlf_number': '52919465',
#    'technical_problem': 'internet_problems',
#    'difficulty': 'hard',
#    'commission': 816.0},
#   'c_a19e341d-7934-44ad-a158-6fad8624dbf0': {'date': '2024-10-23 11:33:01.170031',
#    'tlf_number': '13282939',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'easy',
#    'commission': 560.0},
#   'c_7ed99488-0e7e-4810-b1e0-8a16d2a3fe25': {'date': '2024-10-24 12:43:08.170117',
#    'tlf_number': '93876780',
#    'technical_problem': 'browser_and_web_based_support',
#    'difficulty': 'easy',
#    'commission': 520.0},
#   'c_ddbda0e0-846b-4238-887a-bcf9d4bdc24e': {'date': '2024-10-24 10:13:47.170199',
#    'tlf_number': '08022916',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'hard',
#    'commission': 840.0},
#   'c_09de211b-be14-4f4c-8f2c-96eda2190cb2': {'date': '2024-10-21 07:41:23.170281',
#    'tlf_number': '67669338',
#    'technical_problem': 'email_related_issues',
#    'difficulty': 'easy',
#    'commission': 560.0},
#   'c_cc933d6c-4b00-45d9-8c92-4bbe202c9543': {'date': '2024-10-19 03:32:22.170387',
#    'tlf_number': '60833942',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'hard',
#    'commission': 882.0},
#   'c_aa7f436a-48ab-43f1-9f66-c95609c9dc5c': {'date': '2024-10-22 07:06:34.170504',
#    'tlf_number': '73194492',
#    'technical_problem': 'account_and_security_issues',
#    'difficulty': 'medium',
#    'commission': 710},
#   'c_eab6d168-b331-489d-8e63-1549e0095983': {'date': '2024-10-21 00:02:52.170595',
#    'tlf_number': '14557193',
#    'technical_problem': 'device_and_peripheral_setup',
#    'difficulty': 'hard',
#    'commission': 846.0},
#   'c_06efe38d-f931-42d5-9c8b-9b71290b4a41': {'date': '2024-10-25 03:33:03.170686',
#    'tlf_number': '63175377',
#    'technical_problem': 'operating_system_support',
#    'difficulty': 'medium',
#    'commission': 735},
#   ...}}

# %%
# Load feature calls, previous calls, previous reports, and schedules
future_calls_df = load_and_flatten_data('Week2\calls', 'call_id')
previous_calls_df = load_and_flatten_data('extracted/previous_calls', 'call_id')

# %%
future_calls_df
# Out:
#                              date tlf_number  \
# 0       1970-01-01 00:00:00+00:00   20962728
# 1       1970-01-01 00:00:00+00:00   93884912
# 2       1970-01-01 00:00:00+00:00   34997608
# 3       1970-01-01 00:00:00+00:00   08890010
# 4       1970-01-01 00:00:00+00:00   41021032
# ...                           ...        ...
# 260288  1970-01-01 00:00:00+00:00   21482224
# 260289  1970-01-01 00:00:00+00:00   54350588
# 260290  1970-01-01 00:00:00+00:00   78885138
# 260291  1970-01-01 00:00:00+00:00   48763576
# 260292  1970-01-01 00:00:00+00:00   57423650
#
#                               technical_problem difficulty  commission  \
# 0                   device_and_peripheral_setup     medium       705.0
# 1                   device_and_peripheral_setup       hard       846.0
# 2                          email_related_issues     medium       700.0
# 3       software_installation_and_configuration       easy       600.0
# 4                             internet_problems       hard       816.0
# ...                                         ...        ...         ...
# 260288                     email_related_issues       easy       560.0
# 260289            browser_and_web_based_support       easy       520.0
# 260290  software_installation_and_configuration       easy       600.0
# 260291                           teams_problems       hard       798.0
# 260292                            zoom_problems       easy       556.0
#
#                                        call_id   location
# 0       c_0195b1db-9c43-4a1b-a0ab-241d46b65ccc  bangalore
# 1       c_82aa1a0f-5bf6-49a8-9a32-ceda4b0bea08  bangalore
# 2       c_f26adcb6-1fbd-4c5d-a844-e861dd6088e7  bangalore
# 3       c_a930dc43-76d4-43fe-a6c4-af82427c65b5  bangalore
# 4       c_ee2e7e49-799b-48c0-a0fd-f89a02d7c463  bangalore
# ...                                        ...        ...
# 260288  c_592e71fd-a512-4a6d-ac83-46779c378d42  hyderabad
# 260289  c_fe0eb66a-f7de-4db0-b421-f98b6a1e387c  hyderabad
# 260290  c_4e7ca62b-18d8-45fa-918c-b3da7fa5436b  hyderabad
# 260291  c_fc9f040e-99f1-4785-8fbd-e261632d5ae2  hyderabad
# 260292  c_93ad8b97-7a5e-450f-adae-c8c42797381e  hyderabad
#
# [260293 rows x 7 columns]

# %%
# Load previous and new reports
previous_reports = []
for file_path in glob.glob('extracted/previous_reports/*.json'):
    previous_reports.extend(pd.read_json(file_path).to_dict(orient='records'))
previous_reports_df = pd.DataFrame(previous_reports)

# %%
new_reports = []
for file_path in glob.glob('Week2\call_report_week2/*.json'):
    new_reports.extend(pd.read_json(file_path).to_dict(orient='records'))
new_reports_df = pd.DataFrame(new_reports)

# %%
new_reports_df
# Out:
#                                       call_id  \
# 0      c_0195b1db-9c43-4a1b-a0ab-241d46b65ccc
# 1      c_1cc0ef8a-4014-46ea-a8a5-9fb2d2b996bf
# 2      c_cf015bea-77f5-478c-81c4-168e98ac0a35
# 3      c_f7786fe6-39e3-47c5-8539-f7e716189ef4
# 4      c_edc1511a-d8af-4984-be9c-28bed6dfae93
# ...                                       ...
# 67138  c_33239abc-6fd2-44b4-bb54-1c5d45c1644f
# 67139  c_9b38a1a3-a837-4590-9577-42edaf0ccd3a
# 67140  c_2659df8a-b775-4904-8d45-cf8e9cf0a009
# 67141  c_f9ac151b-9bcc-4327-99cd-7468bcecfa0d
# 67142  c_0d6ccd3b-1059-4819-aae3-8174a52f308e
#
#                                     worker_id  call_time  likely_to_recommend  \
# 0      w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960  45.522797                  1.0
# 1      w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960  30.887813                  1.0
# 2      w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960  64.506471                  1.0
# 3      w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960  64.682155                  1.0
# 4      w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960  15.946662                  7.6
# ...                                       ...        ...                  ...
# 67138  w_f5400776-c6cc-4563-b835-b5ee56242aa1  15.521120                 10.0
# 67139  w_f5400776-c6cc-4563-b835-b5ee56242aa1  15.965120                  9.8
# 67140  w_f5400776-c6cc-4563-b835-b5ee56242aa1  15.867863                  8.5
# 67141  w_f5400776-c6cc-4563-b835-b5ee56242aa1  29.894669                  4.9
# 67142  w_f5400776-c6cc-4563-b835-b5ee56242aa1  21.363210                  6.2
#
#        professional_score  call_profit
# 0                     NaN          705
# 1                     NaN          520
# 2                     NaN          840
# 3                     NaN          834
# 4                     NaN          600
# ...                   ...          ...
# 67138                 NaN          552
# 67139                 NaN          690
# 67140                 NaN          564
# 67141                 NaN          700
# 67142                 NaN          520
#
# [67143 rows x 6 columns]

# %%
previous_reports_df
# Out:
#                                       call_id  \
# 0      c_a317abc5-a7e1-40c3-b486-c4eefdf8be05
# 1      c_256844cb-b710-4da7-8f95-238a7fdd5261
# 2      c_46bfdc38-5130-4e08-9918-4851d84930ce
# 3      c_497ac5ca-8ff3-4773-968c-2e300486c35d
# 4      c_97384374-b420-4259-aaa9-f2e1571928cb
# ...                                       ...
# 72511  c_282338ea-b4a3-4d55-801c-1935c08be259
# 72512  c_9f076c7e-aa1f-44e2-a904-ec7daaec52c4
# 72513  c_bece22d1-0ba0-4208-91f8-366c8267177c
# 72514  c_ac55b479-d0ad-4c68-a637-87b3c360ceb9
# 72515  c_5a9ca763-3a01-491b-9288-e4e17fce0abb
#
#                                     worker_id  call_time  likely_to_recommend  \
# 0      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  57.057332                  1.0
# 1      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  69.294334                  1.0
# 2      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  70.794334                  1.0
# 3      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  54.379299                  1.0
# 4      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  77.457332                  1.0
# ...                                       ...        ...                  ...
# 72511  w_ff6501e8-b49a-4512-a9eb-e06565d21355  37.453295                  1.0
# 72512  w_ff6501e8-b49a-4512-a9eb-e06565d21355  62.093346                  1.0
# 72513  w_ff6501e8-b49a-4512-a9eb-e06565d21355  61.482360                  1.0
# 72514  w_ff6501e8-b49a-4512-a9eb-e06565d21355  32.353295                  1.0
# 72515  w_ff6501e8-b49a-4512-a9eb-e06565d21355  57.151490                  1.0
#
#        professional_score  call_profit
# 0                     NaN          695
# 1                     NaN          735
# 2                     NaN          735
# 3                     NaN          532
# 4                     NaN          834
# ...                   ...          ...
# 72511                 NaN          705
# 72512                 NaN          780
# 72513                 NaN          864
# 72514                 NaN          564
# 72515                 NaN          690
#
# [72516 rows x 6 columns]

# %%
# Combine prices with calls based on technical problems
future_calls_df = future_calls_df.merge(prices_df, on='technical_problem', how='left')
previous_calls_df = previous_calls_df.merge(prices_df, on='technical_problem', how='left')

# %%
# Load previous schedules
schedule_records = []
for file_path in glob.glob('extracted/previous_schedules/*.json'):
    with open(file_path) as f:
        schedules_data = json.load(f)
    for worker_id, calls in schedules_data.items():
        for call_id in calls:
            schedule_records.append({'worker_id': worker_id, 'call_id': call_id})
previous_schedules_df = pd.DataFrame(schedule_records)

# %%
previous_schedules_df
# Out:
#                                      worker_id  \
# 0       w_3cbcf16f-2173-4281-bad0-b5579ba0f123
# 1       w_3cbcf16f-2173-4281-bad0-b5579ba0f123
# 2       w_3cbcf16f-2173-4281-bad0-b5579ba0f123
# 3       w_3cbcf16f-2173-4281-bad0-b5579ba0f123
# 4       w_3cbcf16f-2173-4281-bad0-b5579ba0f123
# ...                                        ...
# 283110  w_ff6501e8-b49a-4512-a9eb-e06565d21355
# 283111  w_ff6501e8-b49a-4512-a9eb-e06565d21355
# 283112  w_ff6501e8-b49a-4512-a9eb-e06565d21355
# 283113  w_ff6501e8-b49a-4512-a9eb-e06565d21355
# 283114  w_ff6501e8-b49a-4512-a9eb-e06565d21355
#
#                                        call_id
# 0       c_a317abc5-a7e1-40c3-b486-c4eefdf8be05
# 1       c_256844cb-b710-4da7-8f95-238a7fdd5261
# 2       c_46bfdc38-5130-4e08-9918-4851d84930ce
# 3       c_497ac5ca-8ff3-4773-968c-2e300486c35d
# 4       c_97384374-b420-4259-aaa9-f2e1571928cb
# ...                                        ...
# 283110  c_bf99f2ec-a582-4123-8b11-28d6a1c39551
# 283111  c_31d6c622-ad70-4772-908c-99768c628e43
# 283112  c_9b26aba2-542f-4ba4-931a-1feb8ffacb8f
# 283113  c_541e5944-02c7-4297-a66a-6f5949bd2688
# 283114  c_13546f61-61c9-483e-b941-c6f3c100a5a9
#
# [283115 rows x 2 columns]

# %%
# Load future schedules
future_schedules = []
for file_path in glob.glob('Week2\call_schedule_Uke2/*.json'):
    with open(file_path) as f:
        schedules_data = json.load(f)
    for worker_id, calls in schedules_data.items():
        for call_id in calls:
            future_schedules.append({'worker_id': worker_id, 'call_id': call_id})
future_schedules_df = pd.DataFrame(future_schedules)

# %%
future_schedules_df
# Out:
#                                      worker_id  \
# 0       w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960
# 1       w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960
# 2       w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960
# 3       w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960
# 4       w_b36ab6fb-e94c-4aa3-84a5-ba2992dd4960
# ...                                        ...
# 260288  w_f5400776-c6cc-4563-b835-b5ee56242aa1
# 260289  w_f5400776-c6cc-4563-b835-b5ee56242aa1
# 260290  w_f5400776-c6cc-4563-b835-b5ee56242aa1
# 260291  w_f5400776-c6cc-4563-b835-b5ee56242aa1
# 260292  w_f5400776-c6cc-4563-b835-b5ee56242aa1
#
#                                        call_id
# 0       c_0195b1db-9c43-4a1b-a0ab-241d46b65ccc
# 1       c_1cc0ef8a-4014-46ea-a8a5-9fb2d2b996bf
# 2       c_cf015bea-77f5-478c-81c4-168e98ac0a35
# 3       c_f7786fe6-39e3-47c5-8539-f7e716189ef4
# 4       c_edc1511a-d8af-4984-be9c-28bed6dfae93
# ...                                        ...
# 260288  c_a703151a-8894-4fe4-b208-514d92c5052c
# 260289  c_0e7226d4-d988-4ee6-a55a-5cf2e6818de3
# 260290  c_a3492ea4-3a2c-4d4a-a915-4503d4312672
# 260291  c_170c7c3a-4228-4192-93a7-c942c8b54828
# 260292  c_e88ca4b8-00bf-480d-85e0-334c24dd11da
#
# [260293 rows x 2 columns]

# %%
# Calculate key performance metrics
def calculate_metrics(report_df):
    return {
        "Average Profit": report_df['call_profit'].mean(),
        "Average Call Time": report_df['call_time'].mean(),
        "Average Recommendation": report_df['likely_to_recommend'].mean(),
        
    }

# %%
future_calls_df
# Out:
#                              date tlf_number  \
# 0       1970-01-01 00:00:00+00:00   20962728
# 1       1970-01-01 00:00:00+00:00   93884912
# 2       1970-01-01 00:00:00+00:00   34997608
# 3       1970-01-01 00:00:00+00:00   08890010
# 4       1970-01-01 00:00:00+00:00   41021032
# ...                           ...        ...
# 260288  1970-01-01 00:00:00+00:00   21482224
# 260289  1970-01-01 00:00:00+00:00   54350588
# 260290  1970-01-01 00:00:00+00:00   78885138
# 260291  1970-01-01 00:00:00+00:00   48763576
# 260292  1970-01-01 00:00:00+00:00   57423650
#
#                               technical_problem difficulty  commission  \
# 0                   device_and_peripheral_setup     medium       705.0
# 1                   device_and_peripheral_setup       hard       846.0
# 2                          email_related_issues     medium       700.0
# 3       software_installation_and_configuration       easy       600.0
# 4                             internet_problems       hard       816.0
# ...                                         ...        ...         ...
# 260288                     email_related_issues       easy       560.0
# 260289            browser_and_web_based_support       easy       520.0
# 260290  software_installation_and_configuration       easy       600.0
# 260291                           teams_problems       hard       798.0
# 260292                            zoom_problems       easy       556.0
#
#                                        call_id   location  price
# 0       c_0195b1db-9c43-4a1b-a0ab-241d46b65ccc  bangalore    705
# 1       c_82aa1a0f-5bf6-49a8-9a32-ceda4b0bea08  bangalore    705
# 2       c_f26adcb6-1fbd-4c5d-a844-e861dd6088e7  bangalore    700
# 3       c_a930dc43-76d4-43fe-a6c4-af82427c65b5  bangalore    750
# 4       c_ee2e7e49-799b-48c0-a0fd-f89a02d7c463  bangalore    680
# ...                                        ...        ...    ...
# 260288  c_592e71fd-a512-4a6d-ac83-46779c378d42  hyderabad    700
# 260289  c_fe0eb66a-f7de-4db0-b421-f98b6a1e387c  hyderabad    650
# 260290  c_4e7ca62b-18d8-45fa-918c-b3da7fa5436b  hyderabad    750
# 260291  c_fc9f040e-99f1-4785-8fbd-e261632d5ae2  hyderabad    665
# 260292  c_93ad8b97-7a5e-450f-adae-c8c42797381e  hyderabad    695
#
# [260293 rows x 8 columns]

# %%
# Calculate metrics for previous and new reports
previous_metrics = calculate_metrics(previous_reports_df)
new_metrics = calculate_metrics(new_reports_df)

# %%
previous_reports_df = previous_reports_df.merge(load_and_flatten_data('extracted/previous_calls', 'call_id'), on='call_id', how='left')
new_reports_df = new_reports_df.merge(load_and_flatten_data('Week2\calls', 'call_id'), on='call_id', how='left')

# %%
previous_reports_df
# Out:
#                                       call_id  \
# 0      c_a317abc5-a7e1-40c3-b486-c4eefdf8be05
# 1      c_256844cb-b710-4da7-8f95-238a7fdd5261
# 2      c_46bfdc38-5130-4e08-9918-4851d84930ce
# 3      c_497ac5ca-8ff3-4773-968c-2e300486c35d
# 4      c_97384374-b420-4259-aaa9-f2e1571928cb
# ...                                       ...
# 72511  c_282338ea-b4a3-4d55-801c-1935c08be259
# 72512  c_9f076c7e-aa1f-44e2-a904-ec7daaec52c4
# 72513  c_bece22d1-0ba0-4208-91f8-366c8267177c
# 72514  c_ac55b479-d0ad-4c68-a637-87b3c360ceb9
# 72515  c_5a9ca763-3a01-491b-9288-e4e17fce0abb
#
#                                     worker_id  call_time  likely_to_recommend  \
# 0      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  57.057332                  1.0
# 1      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  69.294334                  1.0
# 2      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  70.794334                  1.0
# 3      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  54.379299                  1.0
# 4      w_3cbcf16f-2173-4281-bad0-b5579ba0f123  77.457332                  1.0
# ...                                       ...        ...                  ...
# 72511  w_ff6501e8-b49a-4512-a9eb-e06565d21355  37.453295                  1.0
# 72512  w_ff6501e8-b49a-4512-a9eb-e06565d21355  62.093346                  1.0
# 72513  w_ff6501e8-b49a-4512-a9eb-e06565d21355  61.482360                  1.0
# 72514  w_ff6501e8-b49a-4512-a9eb-e06565d21355  32.353295                  1.0
# 72515  w_ff6501e8-b49a-4512-a9eb-e06565d21355  57.151490                  1.0
#
#        professional_score  call_profit                        date tlf_number  \
# 0                     NaN          695  2024-10-19 07:28:55.254686   85062036
# 1                     NaN          735  2024-10-25 08:14:21.255716   56920356
# 2                     NaN          735  2024-10-25 08:05:02.256263   71277349
# 3                     NaN          532  2024-10-25 16:49:01.261099   26307674
# 4                     NaN          834  2024-10-25 13:12:40.265332   44681209
# ...                   ...          ...                         ...        ...
# 72511                 NaN          705  2024-10-24 18:24:02.185299   68091458
# 72512                 NaN          780  2024-10-24 03:11:06.185759   46370406
# 72513                 NaN          864  2024-10-22 12:55:45.188029   38466912
# 72514                 NaN          564  2024-10-20 07:32:03.190272   91733895
# 72515                 NaN          690  2024-10-18 15:38:50.196272   23976720
#
#                     technical_problem difficulty  commission   location
# 0                       zoom_problems     medium       695.0  bangalore
# 1            operating_system_support     medium       735.0  bangalore
# 2            operating_system_support     medium       735.0  bangalore
# 3                      teams_problems       easy       532.0  bangalore
# 4                       zoom_problems       hard       834.0  bangalore
# ...                               ...        ...         ...        ...
# 72511     device_and_peripheral_setup     medium       705.0  hyderabad
# 72512   browser_and_web_based_support       hard       780.0  hyderabad
# 72513  basic_hardware_troubleshooting       hard       864.0  hyderabad
# 72514     device_and_peripheral_setup       easy       564.0  hyderabad
# 72515     cloud_and_storage_solutions     medium       690.0  hyderabad
#
# [72516 rows x 12 columns]

# %%
# Calculate percentage changes
comparison = {
    "Metric": ["Average Profit", "Average Call Time", "Average Recommendation"],
    "Previous": [previous_metrics["Average Profit"], previous_metrics["Average Call Time"], previous_metrics["Average Recommendation"]],
    "New": [new_metrics["Average Profit"], new_metrics["Average Call Time"], new_metrics["Average Recommendation"]],
    "Change (%)": [
        (new_metrics["Average Profit"] - previous_metrics["Average Profit"]) / previous_metrics["Average Profit"] * 100 if previous_metrics["Average Profit"] else None,
        (new_metrics["Average Call Time"] - previous_metrics["Average Call Time"]) / previous_metrics["Average Call Time"] * 100 if previous_metrics["Average Call Time"] else None,
        (new_metrics["Average Recommendation"] - previous_metrics["Average Recommendation"]) / previous_metrics["Average Recommendation"] * 100 if previous_metrics["Average Recommendation"] else None
    ]
}

# Create a DataFrame for comparison
comparison_df = pd.DataFrame(comparison)

# %%
comparison_df
# Out:
#                    Metric    Previous         New  Change (%)
# 0          Average Profit  698.655442  698.894464    0.034212
# 1       Average Call Time   44.539292   43.545245   -2.231845
# 2  Average Recommendation    1.546179    1.544043   -0.138112
